# %%
import collections
import copy
import hashlib
import io
import os
import subprocess
import textwrap
import time

from typing import List, Text

from PIL import Image

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import tabulate


import tensorflow as tf

import matplotlib.pyplot as plt

# %%
from google.colab import auth

# Authenticate user for access. There will be a popup asking you to sign in with your user and approve access.
auth.authenticate_user()

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>1.Defines Global Parameters for GCP </b></h1>
# </div>

# %%
#@title Global params

class Globals:
  # GCP project with GCS bucket of interest
  gcp_project = 'dx-scin-public' #@param

  # GCS bucket with data to read
  gcs_bucket_name = 'dx-scin-public-data' #@param

  # CSV of case metadata to read
  cases_csv = 'dataset/scin_cases.csv' #@param

  # CSV of label metadata to read
  labels_csv = 'dataset/scin_labels.csv' #@param

  # Images directory
  gcs_images_dir = 'dataset/images/' #@param

  ### Key column names
  image_path_columns = ['image_1_path', 'image_2_path', 'image_3_path']
  weighted_skin_condition_label = "weighted_skin_condition_label"
  skin_condition_label = "dermatologist_skin_condition_on_label_name"

  ###### Formed during execution:

  # Client for querying GCS
  gcs_storage_client = None

  # Bucket object for loading files
  gcs_bucket = None

  # pd.DataFrame for the loaded metadata_csv
  cases_df = None

  # pd.DataFrame for the loaded labels_csv
  cases_and_labels_df = None

print(f'GCS bucket name: {Globals.gcs_bucket_name}')
print(f'cases_csv: {Globals.cases_csv}')
print(f'labels_csv: {Globals.labels_csv}')
print(f'images dir: {Globals.gcs_images_dir}')
# Out:
# GCS bucket name: dx-scin-public-data
# cases_csv: dataset/scin_cases.csv
# labels_csv: dataset/scin_labels.csv
# images dir: dataset/images/

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>2.Intialize Google Cloud Storage client to Load CSV label files</b></h1>
# </div>

# %%
#@title Create a dataframe that contains the metadata and condition labels

from google.cloud import storage

def list_blobs(storage_client, bucket_name):
  """Helper to list blobs in a bucket (useful for debugging)."""
  blobs = storage_client.list_blobs(bucket_name)
  for blob in blobs:
    print(blob)

def initialize_df_with_metadata(bucket, csv_path):
  """Loads the given CSV into a pd.DataFrame."""
  df = pd.read_csv(io.BytesIO(bucket.blob(csv_path).download_as_string()), dtype={'case_id': str})
  df['case_id'] = df['case_id'].astype(str)
  return df

def augment_metadata_with_labels(df, bucket, csv_path):
  """Loads the given CSV into a pd.DataFrame."""
  labels_df = pd.read_csv(io.BytesIO(bucket.blob(csv_path).download_as_string()), dtype={'case_id': str})
  labels_df['case_id'] = labels_df['case_id'].astype(str)
  merged_df = pd.merge(df, labels_df, on='case_id')
  return merged_df

Globals.gcs_storage_client = storage.Client(Globals.gcp_project)
Globals.gcs_bucket = Globals.gcs_storage_client.bucket(
    Globals.gcs_bucket_name
)
Globals.cases_df = initialize_df_with_metadata(Globals.gcs_bucket, Globals.cases_csv)
Globals.cases_and_labels_df = augment_metadata_with_labels(Globals.cases_df, Globals.gcs_bucket, Globals.labels_csv)
print(len(Globals.cases_and_labels_df))
# Out:
# 5033

# %%
Globals.cases_and_labels_df.columns
# Out:
# Index(['case_id', 'source', 'release', 'year', 'age_group', 'sex_at_birth',
#        'fitzpatrick_skin_type',
#        'race_ethnicity_american_indian_or_alaska_native',
#        'race_ethnicity_asian', 'race_ethnicity_black_or_african_american',
#        'race_ethnicity_hispanic_latino_or_spanish_origin',
#        'race_ethnicity_middle_eastern_or_north_african',
#        'race_ethnicity_native_hawaiian_or_pacific_islander',
#        'race_ethnicity_white', 'race_ethnicity_other_race',
#        'race_ethnicity_prefer_not_to_answer', 'textures_raised_or_bumpy',
#        'textures_flat', 'textures_rough_or_flaky', 'textures_fluid_filled',
#        'body_parts_head_or_neck', 'body_parts_arm', 'body_parts_palm',
#        'body_parts_back_of_hand', 'body_parts_torso_front',
#        'body_parts_torso_back', 'body_parts_genitalia_or_groin',
#        'body_parts_buttocks', 'body_parts_leg', 'body_parts_foot_top_or_side',
#        'body_parts_foot_sole', 'body_parts_other',
#        'condition_symptoms_bothersome_appearance',
#        'condition_symptoms_bleeding', 'condition_symptoms_increasing_size',
#        'condition_symptoms_darkening', 'condition_symptoms_itching',
#        'condition_symptoms_burning', 'condition_symptoms_pain',
#        'condition_symptoms_no_relevant_experience', 'other_symptoms_fever',
#        'other_symptoms_chills', 'other_symptoms_fatigue',
#        'other_symptoms_joint_pain', 'other_symptoms_mouth_sores',
#        'other_symptoms_shortness_of_breath',
#        'other_symptoms_no_relevant_symptoms', 'related_category',
#        'condition_duration', 'image_1_path', 'image_2_path', 'image_3_path',
#        'image_1_shot_type', 'image_2_shot_type', 'image_3_shot_type',
#        'combined_race', 'race_ethnicity_two_or_more_after_mitigation',
#        'dermatologist_gradable_for_skin_condition_1',
#        'dermatologist_gradable_for_skin_condition_2',
#        'dermatologist_gradable_for_skin_condition_3',
#        'dermatologist_skin_condition_on_label_name',
#        'dermatologist_skin_condition_confidence',
#        'weighted_skin_condition_label',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_1',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_2',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_3',
#        'dermatologist_fitzpatrick_skin_type_label_1',
#        'dermatologist_fitzpatrick_skin_type_label_2',
#        'dermatologist_fitzpatrick_skin_type_label_3',
#        'gradable_for_monk_skin_tone_india', 'gradable_for_monk_skin_tone_us',
#        'monk_skin_tone_label_india', 'monk_skin_tone_label_us'],
#       dtype='object')

# %%
Globals.cases_and_labels_df.head(5)
# Out:
#                 case_id source release  year     age_group  \
# 0  -1000600354148496558   SCIN   1.0.0  2023   AGE_UNKNOWN
# 1  -1002039107727665188   SCIN   1.0.0  2023   AGE_UNKNOWN
# 2  -1003358831658393077   SCIN   1.0.0  2023  AGE_18_TO_29
# 3  -1003826561155964328   SCIN   1.0.0  2023   AGE_UNKNOWN
# 4  -1003844406100696311   SCIN   1.0.0  2023  AGE_40_TO_49
#
#            sex_at_birth fitzpatrick_skin_type  \
# 0  OTHER_OR_UNSPECIFIED                   NaN
# 1  OTHER_OR_UNSPECIFIED                   NaN
# 2                  MALE       NONE_IDENTIFIED
# 3  OTHER_OR_UNSPECIFIED                   NaN
# 4                FEMALE                  FST3
#
#   race_ethnicity_american_indian_or_alaska_native race_ethnicity_asian  \
# 0                                             NaN                  NaN
# 1                                             NaN                  NaN
# 2                                             NaN                  NaN
# 3                                             NaN                  NaN
# 4                                             NaN                  NaN
#
#   race_ethnicity_black_or_african_american  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   race_ethnicity_hispanic_latino_or_spanish_origin  \
# 0                                              NaN
# 1                                              NaN
# 2                                              YES
# 3                                              NaN
# 4                                              NaN
#
#   race_ethnicity_middle_eastern_or_north_african  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   race_ethnicity_native_hawaiian_or_pacific_islander race_ethnicity_white  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  YES
#
#   race_ethnicity_other_race race_ethnicity_prefer_not_to_answer  \
# 0                       NaN                                 NaN
# 1                       NaN                                 NaN
# 2                       NaN                                 NaN
# 3                       NaN                                 NaN
# 4                       NaN                                 NaN
#
#   textures_raised_or_bumpy textures_flat textures_rough_or_flaky  \
# 0                      YES           NaN                     NaN
# 1                      NaN           NaN                     NaN
# 2                      NaN           YES                     YES
# 3                      YES           NaN                     YES
# 4                      NaN           YES                     NaN
#
#   textures_fluid_filled body_parts_head_or_neck body_parts_arm  \
# 0                   NaN                     NaN            NaN
# 1                   NaN                     NaN            NaN
# 2                   NaN                     NaN            YES
# 3                   NaN                     NaN            NaN
# 4                   NaN                     YES            YES
#
#   body_parts_palm body_parts_back_of_hand body_parts_torso_front  \
# 0             NaN                     NaN                    NaN
# 1             NaN                     NaN                    NaN
# 2             NaN                     NaN                    NaN
# 3             YES                     NaN                    NaN
# 4             NaN                     YES                    YES
#
#   body_parts_torso_back body_parts_genitalia_or_groin body_parts_buttocks  \
# 0                   NaN                           NaN                 NaN
# 1                   NaN                           NaN                 NaN
# 2                   NaN                           NaN                 NaN
# 3                   NaN                           NaN                 NaN
# 4                   YES                           YES                 YES
#
#   body_parts_leg body_parts_foot_top_or_side body_parts_foot_sole  \
# 0            NaN                         YES                  NaN
# 1            NaN                         NaN                  NaN
# 2            NaN                         NaN                  NaN
# 3            NaN                         NaN                  NaN
# 4            YES                         YES                  NaN
#
#   body_parts_other condition_symptoms_bothersome_appearance  \
# 0              NaN                                      NaN
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
#
#   condition_symptoms_bleeding condition_symptoms_increasing_size  \
# 0                         YES                                YES
# 1                         NaN                                NaN
# 2                         NaN                                YES
# 3                         NaN                                NaN
# 4                         NaN                                NaN
#
#   condition_symptoms_darkening condition_symptoms_itching  \
# 0                          NaN                        YES
# 1                          NaN                        NaN
# 2                          NaN                        YES
# 3                          NaN                        YES
# 4                          NaN                        YES
#
#   condition_symptoms_burning condition_symptoms_pain  \
# 0                        YES                     YES
# 1                        NaN                     NaN
# 2                        YES                     YES
# 3                        YES                     YES
# 4                        NaN                     NaN
#
#   condition_symptoms_no_relevant_experience other_symptoms_fever  \
# 0                                       NaN                  NaN
# 1                                       NaN                  NaN
# 2                                       NaN                  NaN
# 3                                       NaN                  NaN
# 4                                       NaN                  NaN
#
#   other_symptoms_chills other_symptoms_fatigue other_symptoms_joint_pain  \
# 0                   NaN                    NaN                       NaN
# 1                   NaN                    NaN                       NaN
# 2                   NaN                    NaN                       NaN
# 3                   NaN                    NaN                       NaN
# 4                   NaN                    NaN                       NaN
#
#   other_symptoms_mouth_sores other_symptoms_shortness_of_breath  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                NaN
# 3                        NaN                                NaN
# 4                        NaN                                NaN
#
#   other_symptoms_no_relevant_symptoms         related_category  \
# 0                                 YES                     RASH
# 1                                 NaN                      NaN
# 2                                 YES  OTHER_ISSUE_DESCRIPTION
# 3                                 YES  OTHER_ISSUE_DESCRIPTION
# 4                                 YES                     RASH
#
#   condition_duration                             image_1_path  \
# 0            ONE_DAY  dataset/images/-3205742176803893704.png
# 1                NaN  dataset/images/-4762289084741430925.png
# 2  ONE_TO_FOUR_WEEKS  dataset/images/-4027806997035329030.png
# 3            ONE_DAY  dataset/images/-5332065579713135540.png
# 4            ONE_DAY  dataset/images/-3799298995660217860.png
#
#                               image_2_path  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  dataset/images/-6353431708064969797.png
# 4  dataset/images/-5881426422999442186.png
#
#                              image_3_path image_1_shot_type image_2_shot_type  \
# 0                                     NaN          CLOSE_UP               NaN
# 1                                     NaN          CLOSE_UP               NaN
# 2                                     NaN          CLOSE_UP               NaN
# 3   dataset/images/742075435141960831.png       AT_DISTANCE       AT_AN_ANGLE
# 4  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
#
#   image_3_shot_type                      combined_race  \
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 3          CLOSE_UP                                NaN
# 4          CLOSE_UP                              WHITE
#
#   race_ethnicity_two_or_more_after_mitigation  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   dermatologist_gradable_for_skin_condition_1  \
# 0        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 1        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 3               NO_IMAGE_QUALITY_INSUFFICIENT
# 4        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#   dermatologist_gradable_for_skin_condition_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   dermatologist_gradable_for_skin_condition_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#           dermatologist_skin_condition_on_label_name  \
# 0  ['Inflicted skin lesions', 'Eczema', 'Irritant...
# 1  ['Prurigo nodularis', 'Actinic Keratosis', 'SC...
# 2  ['Impetigo', 'Herpes Zoster', 'Bullous dermati...
# 3                                                 []
# 4  ['Lichen planus/lichenoid eruption', 'Follicul...
#
#   dermatologist_skin_condition_confidence  \
# 0                               [4, 4, 3]
# 1                               [4, 3, 4]
# 2                               [2, 1, 1]
# 3                                      []
# 4                               [1, 1, 1]
#
#                        weighted_skin_condition_label  \
# 0  {'Inflicted skin lesions': 0.41, 'Eczema': 0.4...
# 1  {'Prurigo nodularis': 0.41, 'SCC/SCCIS': 0.41,...
# 2  {'Impetigo': 0.55, 'Herpes Zoster': 0.23, 'Bul...
# 3                                                 {}
# 4  {'Lichen planus/lichenoid eruption': 0.33, 'Fo...
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_1  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                 NO
# 4                                                YES
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   dermatologist_fitzpatrick_skin_type_label_1  \
# 0                                        FST2
# 1                                        FST1
# 2                                        FST4
# 3                                         NaN
# 4                                        FST1
#
#   dermatologist_fitzpatrick_skin_type_label_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   dermatologist_fitzpatrick_skin_type_label_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   gradable_for_monk_skin_tone_india gradable_for_monk_skin_tone_us  \
# 0                              True                           True
# 1                              True                           True
# 2                              True                           True
# 3                              True                           True
# 4                              True                           True
#
#    monk_skin_tone_label_india  monk_skin_tone_label_us
# 0                         2.0                      1.0
# 1                         3.0                      3.0
# 2                         3.0                      4.0
# 3                         2.0                      4.0
# 4                         1.0                      1.0

# %%
Globals.cases_and_labels_df.to_csv('Original_dataset.csv')

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>3.Display the random images </b></h1>
# </div>

# %%
#@title Display the images for a case (and condition labels, optionally)
import random
import io
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

def display_image(bucket, image_path):
  image = Image.open(io.BytesIO(bucket.blob(image_path).download_as_string()))
  figure_size=4
  f, axarr = plt.subplots(1, 1, figsize = (figure_size, figure_size))
  axarr.imshow(image, cmap='gray')
  axarr.axis('off')
  plt.show()

def display_images_for_case(df, case_id="", print_condition_labels=True):
  # Use a random case if none is provided:
  if case_id:
    matched_df = df[df['case_id'] == case_id]
  else:
    matched_df = df.sample(1)

  image_paths = matched_df[Globals.image_path_columns].values.tolist()[0]
  for path in image_paths:
    if isinstance(path, str):
      display_image(Globals.gcs_bucket, path)
  if print_condition_labels:
    condition_labels = matched_df[[Globals.weighted_skin_condition_label]].values.tolist()[0]
    for label in condition_labels:
      if isinstance(label, str):
        print(label)

# display_images_for_case(Globals.cases_and_labels_df, "-1000600354148496558")
display_images_for_case(Globals.cases_and_labels_df)
# Out:
# {'Folliculitis': 0.4, 'Acute dermatitis, NOS': 0.17, 'Milia': 0.1, 'Granuloma annulare': 0.1, 'CD - Contact dermatitis': 0.23}

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>4.Get the Missing Images </b></h1>
# </div>

# %%
"""def is_valid_image_path(path):
    if isinstance(path, str):
        try:
            image = Image.open(io.BytesIO(Globals.gcs_bucket.blob(path).download_as_string()))
            return True
        except Exception as e:
            print(f"Invalid image path: {path}, Error: {e}")
            return False
    return False

# Apply the function to the image path columns in the dataframe
image_path_columns = ['image_1_path', 'image_2_path', 'image_3_path']
for col in image_path_columns:
    Globals.cases_and_labels_df[col + '_valid'] = Globals.cases_and_labels_df[col].apply(is_valid_image_path)

# Display the first few rows of the dataframe with validity columns
print(Globals.cases_and_labels_df.head())"""
# Out:
# 'def is_valid_image_path(path):\n    if isinstance(path, str):\n        try:\n            image = Image.open(io.BytesIO(Globals.gcs_bucket.blob(path).download_as_string()))\n            return True\n        except Exception as e:\n            print(f"Invalid image path: {path}, Error: {e}")\n            return False\n    return False\n\n# Apply the function to the image path columns in the dataframe\nimage_path_columns = [\'image_1_path\', \'image_2_path\', \'image_3_path\']\nfor col in image_path_columns:\n    Globals.cases_and_labels_df[col + \'_valid\'] = Globals.cases_and_labels_df[col].apply(is_valid_image_path)\n\n# Display the first few rows of the dataframe with validity columns\nprint(Globals.cases_and_labels_df.head())'

# %% [markdown]
# ## The missing image path is : "**dataset/images/-2243186711511406658.png**"

# %%
Globals.cases_and_labels_df.loc[Globals.cases_and_labels_df['image_1_path'] == ' dataset/images/-2243186711511406658.png', 'image_1_path'] = ''

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>5.Reverse Engineering</b></h1>
# </div>

# %%
one_hot_groups = {
    'race_ethnicity': [
        'race_ethnicity_american_indian_or_alaska_native',
        'race_ethnicity_asian', 'race_ethnicity_black_or_african_american',
        'race_ethnicity_hispanic_latino_or_spanish_origin',
        'race_ethnicity_middle_eastern_or_north_african',
        'race_ethnicity_native_hawaiian_or_pacific_islander',
        'race_ethnicity_white', 'race_ethnicity_other_race',
        'race_ethnicity_prefer_not_to_answer'
    ],
    'textures': [
        'textures_raised_or_bumpy', 'textures_flat',
        'textures_rough_or_flaky', 'textures_fluid_filled'
    ],
    'body_parts': [
        'body_parts_head_or_neck', 'body_parts_arm', 'body_parts_palm',
        'body_parts_back_of_hand', 'body_parts_torso_front',
        'body_parts_torso_back', 'body_parts_genitalia_or_groin',
        'body_parts_buttocks', 'body_parts_leg', 'body_parts_foot_top_or_side',
        'body_parts_foot_sole', 'body_parts_other'
    ],
    'condition_symptoms': [
        'condition_symptoms_bothersome_appearance',
        'condition_symptoms_bleeding', 'condition_symptoms_increasing_size',
        'condition_symptoms_darkening', 'condition_symptoms_itching',
        'condition_symptoms_burning', 'condition_symptoms_pain',
        'condition_symptoms_no_relevant_experience'
    ],
    'other_symptoms': [
        'other_symptoms_fever', 'other_symptoms_chills', 'other_symptoms_fatigue',
        'other_symptoms_joint_pain', 'other_symptoms_mouth_sores',
        'other_symptoms_shortness_of_breath', 'other_symptoms_no_relevant_symptoms'
    ]
}

# Iterate over each group in the one_hot_groups dictionary
for group, columns in one_hot_groups.items():
    # Create a new column with the group name
    Globals.cases_and_labels_df[group] = ''

    # Iterate over each column in the group
    for column in columns:
        # Update the new column with the category name where the corresponding one-hot encoded column is 'YES'
        Globals.cases_and_labels_df.loc[Globals.cases_and_labels_df[column] == 'YES', group] = column

# Print the columns of the updated DataFrame
print(Globals.cases_and_labels_df.columns)
# Out:
# Index(['case_id', 'source', 'release', 'year', 'age_group', 'sex_at_birth',
#        'fitzpatrick_skin_type',
#        'race_ethnicity_american_indian_or_alaska_native',
#        'race_ethnicity_asian', 'race_ethnicity_black_or_african_american',
#        'race_ethnicity_hispanic_latino_or_spanish_origin',
#        'race_ethnicity_middle_eastern_or_north_african',
#        'race_ethnicity_native_hawaiian_or_pacific_islander',
#        'race_ethnicity_white', 'race_ethnicity_other_race',
#        'race_ethnicity_prefer_not_to_answer', 'textures_raised_or_bumpy',
#        'textures_flat', 'textures_rough_or_flaky', 'textures_fluid_filled',
#        'body_parts_head_or_neck', 'body_parts_arm', 'body_parts_palm',
#        'body_parts_back_of_hand', 'body_parts_torso_front',
#        'body_parts_torso_back', 'body_parts_genitalia_or_groin',
#        'body_parts_buttocks', 'body_parts_leg', 'body_parts_foot_top_or_side',
#        'body_parts_foot_sole', 'body_parts_other',
#        'condition_symptoms_bothersome_appearance',
#        'condition_symptoms_bleeding', 'condition_symptoms_increasing_size',
#        'condition_symptoms_darkening', 'condition_symptoms_itching',
#        'condition_symptoms_burning', 'condition_symptoms_pain',
#        'condition_symptoms_no_relevant_experience', 'other_symptoms_fever',
#        'other_symptoms_chills', 'other_symptoms_fatigue',
#        'other_symptoms_joint_pain', 'other_symptoms_mouth_sores',
#        'other_symptoms_shortness_of_breath',
#        'other_symptoms_no_relevant_symptoms', 'related_category',
#        'condition_duration', 'image_1_path', 'image_2_path', 'image_3_path',
#        'image_1_shot_type', 'image_2_shot_type', 'image_3_shot_type',
#        'combined_race', 'race_ethnicity_two_or_more_after_mitigation',
#        'dermatologist_gradable_for_skin_condition_1',
#        'dermatologist_gradable_for_skin_condition_2',
#        'dermatologist_gradable_for_skin_condition_3',
#        'dermatologist_skin_condition_on_label_name',
#        'dermatologist_skin_condition_confidence',
#        'weighted_skin_condition_label',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_1',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_2',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_3',
#        'dermatologist_fitzpatrick_skin_type_label_1',
#        'dermatologist_fitzpatrick_skin_type_label_2',
#        'dermatologist_fitzpatrick_skin_type_label_3',
#        'gradable_for_monk_skin_tone_india', 'gradable_for_monk_skin_tone_us',
#        'monk_skin_tone_label_india', 'monk_skin_tone_label_us',
#        'race_ethnicity', 'textures', 'body_parts', 'condition_symptoms',
#        'other_symptoms'],
#       dtype='object')

# %%
Globals.cases_and_labels_df.head(10)
# Out:
#                 case_id source release  year     age_group  \
# 0  -1000600354148496558   SCIN   1.0.0  2023   AGE_UNKNOWN
# 1  -1002039107727665188   SCIN   1.0.0  2023   AGE_UNKNOWN
# 2  -1003358831658393077   SCIN   1.0.0  2023  AGE_18_TO_29
# 3  -1003826561155964328   SCIN   1.0.0  2023   AGE_UNKNOWN
# 4  -1003844406100696311   SCIN   1.0.0  2023  AGE_40_TO_49
# 5  -1005079160214352144   SCIN   1.0.0  2023   AGE_UNKNOWN
# 6  -1010778459521153386   SCIN   1.0.0  2023  AGE_40_TO_49
# 7  -1013831220015814987   SCIN   1.0.0  2023   AGE_UNKNOWN
# 8   -101827005996397499   SCIN   1.0.0  2023  AGE_18_TO_29
# 9  -1022162013984621110   SCIN   1.0.0  2023   AGE_UNKNOWN
#
#            sex_at_birth fitzpatrick_skin_type  \
# 0  OTHER_OR_UNSPECIFIED                   NaN
# 1  OTHER_OR_UNSPECIFIED                   NaN
# 2                  MALE       NONE_IDENTIFIED
# 3  OTHER_OR_UNSPECIFIED                   NaN
# 4                FEMALE                  FST3
# 5  OTHER_OR_UNSPECIFIED                   NaN
# 6                FEMALE                  FST1
# 7                  MALE                  FST4
# 8                  MALE                  FST2
# 9  OTHER_OR_UNSPECIFIED                   NaN
#
#   race_ethnicity_american_indian_or_alaska_native race_ethnicity_asian  \
# 0                                             NaN                  NaN
# 1                                             NaN                  NaN
# 2                                             NaN                  NaN
# 3                                             NaN                  NaN
# 4                                             NaN                  NaN
# 5                                             NaN                  NaN
# 6                                             NaN                  NaN
# 7                                             NaN                  NaN
# 8                                             NaN                  NaN
# 9                                             NaN                  NaN
#
#   race_ethnicity_black_or_african_american  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
#
#   race_ethnicity_hispanic_latino_or_spanish_origin  \
# 0                                              NaN
# 1                                              NaN
# 2                                              YES
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              YES
# 7                                              NaN
# 8                                              YES
# 9                                              NaN
#
#   race_ethnicity_middle_eastern_or_north_african  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9                                            NaN
#
#   race_ethnicity_native_hawaiian_or_pacific_islander race_ethnicity_white  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                NaN                  YES
# 5                                                NaN                  NaN
# 6                                                NaN                  NaN
# 7                                                NaN                  YES
# 8                                                NaN                  NaN
# 9                                                NaN                  NaN
#
#   race_ethnicity_other_race race_ethnicity_prefer_not_to_answer  \
# 0                       NaN                                 NaN
# 1                       NaN                                 NaN
# 2                       NaN                                 NaN
# 3                       NaN                                 NaN
# 4                       NaN                                 NaN
# 5                       NaN                                 NaN
# 6                       NaN                                 NaN
# 7                       NaN                                 NaN
# 8                       NaN                                 NaN
# 9                       NaN                                 NaN
#
#   textures_raised_or_bumpy textures_flat textures_rough_or_flaky  \
# 0                      YES           NaN                     NaN
# 1                      NaN           NaN                     NaN
# 2                      NaN           YES                     YES
# 3                      YES           NaN                     YES
# 4                      NaN           YES                     NaN
# 5                      YES           NaN                     NaN
# 6                      YES           NaN                     NaN
# 7                      YES           NaN                     NaN
# 8                      NaN           YES                     NaN
# 9                      NaN           NaN                     NaN
#
#   textures_fluid_filled body_parts_head_or_neck body_parts_arm  \
# 0                   NaN                     NaN            NaN
# 1                   NaN                     NaN            NaN
# 2                   NaN                     NaN            YES
# 3                   NaN                     NaN            NaN
# 4                   NaN                     YES            YES
# 5                   NaN                     YES            YES
# 6                   NaN                     YES            YES
# 7                   NaN                     NaN            NaN
# 8                   NaN                     NaN            YES
# 9                   NaN                     NaN            NaN
#
#   body_parts_palm body_parts_back_of_hand body_parts_torso_front  \
# 0             NaN                     NaN                    NaN
# 1             NaN                     NaN                    NaN
# 2             NaN                     NaN                    NaN
# 3             YES                     NaN                    NaN
# 4             NaN                     YES                    YES
# 5             YES                     YES                    NaN
# 6             YES                     NaN                    NaN
# 7             NaN                     NaN                    NaN
# 8             NaN                     NaN                    NaN
# 9             NaN                     NaN                    NaN
#
#   body_parts_torso_back body_parts_genitalia_or_groin body_parts_buttocks  \
# 0                   NaN                           NaN                 NaN
# 1                   NaN                           NaN                 NaN
# 2                   NaN                           NaN                 NaN
# 3                   NaN                           NaN                 NaN
# 4                   YES                           YES                 YES
# 5                   YES                           YES                 NaN
# 6                   NaN                           NaN                 NaN
# 7                   YES                           NaN                 NaN
# 8                   NaN                           NaN                 NaN
# 9                   NaN                           NaN                 NaN
#
#   body_parts_leg body_parts_foot_top_or_side body_parts_foot_sole  \
# 0            NaN                         YES                  NaN
# 1            NaN                         NaN                  NaN
# 2            NaN                         NaN                  NaN
# 3            NaN                         NaN                  NaN
# 4            YES                         YES                  NaN
# 5            NaN                         NaN                  NaN
# 6            NaN                         NaN                  NaN
# 7            NaN                         NaN                  NaN
# 8            NaN                         NaN                  NaN
# 9            NaN                         NaN                  NaN
#
#   body_parts_other condition_symptoms_bothersome_appearance  \
# 0              NaN                                      NaN
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      YES
# 6              NaN                                      NaN
# 7              NaN                                      NaN
# 8              NaN                                      NaN
# 9              NaN                                      NaN
#
#   condition_symptoms_bleeding condition_symptoms_increasing_size  \
# 0                         YES                                YES
# 1                         NaN                                NaN
# 2                         NaN                                YES
# 3                         NaN                                NaN
# 4                         NaN                                NaN
# 5                         NaN                                NaN
# 6                         NaN                                YES
# 7                         NaN                                NaN
# 8                         NaN                                NaN
# 9                         NaN                                NaN
#
#   condition_symptoms_darkening condition_symptoms_itching  \
# 0                          NaN                        YES
# 1                          NaN                        NaN
# 2                          NaN                        YES
# 3                          NaN                        YES
# 4                          NaN                        YES
# 5                          NaN                        YES
# 6                          NaN                        YES
# 7                          NaN                        YES
# 8                          YES                        NaN
# 9                          NaN                        NaN
#
#   condition_symptoms_burning condition_symptoms_pain  \
# 0                        YES                     YES
# 1                        NaN                     NaN
# 2                        YES                     YES
# 3                        YES                     YES
# 4                        NaN                     NaN
# 5                        NaN                     NaN
# 6                        YES                     NaN
# 7                        NaN                     YES
# 8                        NaN                     NaN
# 9                        NaN                     NaN
#
#   condition_symptoms_no_relevant_experience other_symptoms_fever  \
# 0                                       NaN                  NaN
# 1                                       NaN                  NaN
# 2                                       NaN                  NaN
# 3                                       NaN                  NaN
# 4                                       NaN                  NaN
# 5                                       NaN                  NaN
# 6                                       NaN                  NaN
# 7                                       NaN                  NaN
# 8                                       NaN                  NaN
# 9                                       NaN                  NaN
#
#   other_symptoms_chills other_symptoms_fatigue other_symptoms_joint_pain  \
# 0                   NaN                    NaN                       NaN
# 1                   NaN                    NaN                       NaN
# 2                   NaN                    NaN                       NaN
# 3                   NaN                    NaN                       NaN
# 4                   NaN                    NaN                       NaN
# 5                   NaN                    NaN                       NaN
# 6                   NaN                    NaN                       NaN
# 7                   NaN                    NaN                       NaN
# 8                   NaN                    NaN                       NaN
# 9                   NaN                    NaN                       NaN
#
#   other_symptoms_mouth_sores other_symptoms_shortness_of_breath  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                NaN
# 3                        NaN                                NaN
# 4                        NaN                                NaN
# 5                        NaN                                NaN
# 6                        NaN                                NaN
# 7                        NaN                                NaN
# 8                        NaN                                NaN
# 9                        NaN                                NaN
#
#   other_symptoms_no_relevant_symptoms         related_category  \
# 0                                 YES                     RASH
# 1                                 NaN                      NaN
# 2                                 YES  OTHER_ISSUE_DESCRIPTION
# 3                                 YES  OTHER_ISSUE_DESCRIPTION
# 4                                 YES                     RASH
# 5                                 YES                     RASH
# 6                                 YES                     RASH
# 7                                 YES                     RASH
# 8                                 YES                     RASH
# 9                                 NaN                      NaN
#
#     condition_duration                             image_1_path  \
# 0              ONE_DAY  dataset/images/-3205742176803893704.png
# 1                  NaN  dataset/images/-4762289084741430925.png
# 2    ONE_TO_FOUR_WEEKS  dataset/images/-4027806997035329030.png
# 3              ONE_DAY  dataset/images/-5332065579713135540.png
# 4              ONE_DAY  dataset/images/-3799298995660217860.png
# 5   LESS_THAN_ONE_WEEK  dataset/images/-3575683440831198879.png
# 6   LESS_THAN_ONE_WEEK  dataset/images/-6942912841265248602.png
# 7  ONE_TO_THREE_MONTHS   dataset/images/-220649468572111832.png
# 8  ONE_TO_THREE_MONTHS   dataset/images/-217828380359571871.png
# 9                  NaN   dataset/images/8406712750126834903.png
#
#                               image_2_path  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  dataset/images/-6353431708064969797.png
# 4  dataset/images/-5881426422999442186.png
# 5   dataset/images/6164754101533643044.png
# 6   dataset/images/-815168034213335912.png
# 7                                      NaN
# 8  dataset/images/-4055728304670056584.png
# 9                                      NaN
#
#                              image_3_path image_1_shot_type image_2_shot_type  \
# 0                                     NaN          CLOSE_UP               NaN
# 1                                     NaN          CLOSE_UP               NaN
# 2                                     NaN          CLOSE_UP               NaN
# 3   dataset/images/742075435141960831.png       AT_DISTANCE       AT_AN_ANGLE
# 4  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
# 5  dataset/images/7125798012232703466.png          CLOSE_UP       AT_AN_ANGLE
# 6  dataset/images/8479707042238010445.png       AT_AN_ANGLE       AT_DISTANCE
# 7                                     NaN          CLOSE_UP               NaN
# 8                                     NaN          CLOSE_UP       AT_AN_ANGLE
# 9                                     NaN          CLOSE_UP               NaN
#
#   image_3_shot_type                      combined_race  \
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 3          CLOSE_UP                                NaN
# 4          CLOSE_UP                              WHITE
# 5       AT_DISTANCE                                NaN
# 6          CLOSE_UP  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 7               NaN                              WHITE
# 8               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 9               NaN                                NaN
#
#   race_ethnicity_two_or_more_after_mitigation  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
#
#   dermatologist_gradable_for_skin_condition_1  \
# 0        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 1        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 3               NO_IMAGE_QUALITY_INSUFFICIENT
# 4        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 5        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 6               NO_IMAGE_QUALITY_INSUFFICIENT
# 7        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 8        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 9        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#   dermatologist_gradable_for_skin_condition_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 7                                         NaN
# 8        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 9                                         NaN
#
#   dermatologist_gradable_for_skin_condition_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 7                                         NaN
# 8        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 9                                         NaN
#
#           dermatologist_skin_condition_on_label_name  \
# 0  ['Inflicted skin lesions', 'Eczema', 'Irritant...
# 1  ['Prurigo nodularis', 'Actinic Keratosis', 'SC...
# 2  ['Impetigo', 'Herpes Zoster', 'Bullous dermati...
# 3                                                 []
# 4  ['Lichen planus/lichenoid eruption', 'Follicul...
# 5          ['Drug Rash', 'Viral Exanthem', 'Eczema']
# 6  ['Urticaria', 'Leukocytoclastic Vasculitis', '...
# 7  ['Inflicted skin lesions', 'Basal Cell Carcino...
# 8  ['Psoriasis', 'Eczema', 'Eczema', 'Acute and c...
# 9                                        ['Purpura']
#
#   dermatologist_skin_condition_confidence  \
# 0                               [4, 4, 3]
# 1                               [4, 3, 4]
# 2                               [2, 1, 1]
# 3                                      []
# 4                               [1, 1, 1]
# 5                               [2, 2, 1]
# 6                         [4, 2, 5, 1, 1]
# 7                               [2, 4, 1]
# 8                      [1, 3, 3, 2, 4, 3]
# 9                                     [3]
#
#                        weighted_skin_condition_label  \
# 0  {'Inflicted skin lesions': 0.41, 'Eczema': 0.4...
# 1  {'Prurigo nodularis': 0.41, 'SCC/SCCIS': 0.41,...
# 2  {'Impetigo': 0.55, 'Herpes Zoster': 0.23, 'Bul...
# 3                                                 {}
# 4  {'Lichen planus/lichenoid eruption': 0.33, 'Fo...
# 5  {'Drug Rash': 0.41, 'Viral Exanthem': 0.41, 'E...
# 6  {'Urticaria': 0.6, 'Leukocytoclastic Vasculiti...
# 7  {'Basal Cell Carcinoma': 0.55, 'Inflicted skin...
# 8  {'Eczema': 0.67, 'Psoriasis': 0.11, 'Acute and...
# 9                                   {'Purpura': 1.0}
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_1  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                 NO
# 4                                                YES
# 5                                                YES
# 6                                                YES
# 7                                                YES
# 8                                                YES
# 9                                                YES
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_2  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                YES
# 7                                                NaN
# 8                                                YES
# 9                                                NaN
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_3  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                YES
# 7                                                NaN
# 8                                                YES
# 9                                                NaN
#
#   dermatologist_fitzpatrick_skin_type_label_1  \
# 0                                        FST2
# 1                                        FST1
# 2                                        FST4
# 3                                         NaN
# 4                                        FST1
# 5                                        FST3
# 6                                        FST4
# 7                                        FST3
# 8                                        FST3
# 9                                        FST4
#
#   dermatologist_fitzpatrick_skin_type_label_2  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                        FST3
# 7                                         NaN
# 8                                        FST4
# 9                                         NaN
#
#   dermatologist_fitzpatrick_skin_type_label_3  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                        FST4
# 7                                         NaN
# 8                                        FST4
# 9                                         NaN
#
#   gradable_for_monk_skin_tone_india gradable_for_monk_skin_tone_us  \
# 0                              True                           True
# 1                              True                           True
# 2                              True                           True
# 3                              True                           True
# 4                              True                           True
# 5                              True                           True
# 6                              True                           True
# 7                              True                           True
# 8                              True                           True
# 9                              True                           True
#
#    monk_skin_tone_label_india  monk_skin_tone_label_us  \
# 0                         2.0                      1.0
# 1                         3.0                      3.0
# 2                         3.0                      4.0
# 3                         2.0                      4.0
# 4                         1.0                      1.0
# 5                         2.0                      2.0
# 6                         3.0                      3.0
# 7                         3.0                      4.0
# 8                         2.0                      4.0
# 9                         3.0                      3.0
#
#                                      race_ethnicity                  textures  \
# 0                                                    textures_raised_or_bumpy
# 1
# 2  race_ethnicity_hispanic_latino_or_spanish_origin   textures_rough_or_flaky
# 3                                                     textures_rough_or_flaky
# 4                              race_ethnicity_white             textures_flat
# 5                                                    textures_raised_or_bumpy
# 6  race_ethnicity_hispanic_latino_or_spanish_origin  textures_raised_or_bumpy
# 7                              race_ethnicity_white  textures_raised_or_bumpy
# 8  race_ethnicity_hispanic_latino_or_spanish_origin             textures_flat
# 9
#
#                       body_parts            condition_symptoms  \
# 0    body_parts_foot_top_or_side       condition_symptoms_pain
# 1
# 2                 body_parts_arm       condition_symptoms_pain
# 3                body_parts_palm       condition_symptoms_pain
# 4    body_parts_foot_top_or_side    condition_symptoms_itching
# 5  body_parts_genitalia_or_groin    condition_symptoms_itching
# 6                body_parts_palm    condition_symptoms_burning
# 7          body_parts_torso_back       condition_symptoms_pain
# 8                 body_parts_arm  condition_symptoms_darkening
# 9
#
#                         other_symptoms
# 0  other_symptoms_no_relevant_symptoms
# 1
# 2  other_symptoms_no_relevant_symptoms
# 3  other_symptoms_no_relevant_symptoms
# 4  other_symptoms_no_relevant_symptoms
# 5  other_symptoms_no_relevant_symptoms
# 6  other_symptoms_no_relevant_symptoms
# 7  other_symptoms_no_relevant_symptoms
# 8  other_symptoms_no_relevant_symptoms
# 9

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>6.Drop One Hot Encoded Columns </b></h1>
# </div>

# %%
# List to store columns to be dropped
columns_to_drop = []

# Iterate over each column in the original DataFrame
for column in Globals.cases_and_labels_df.columns:
    # Check if the column name starts with any prefix in the one_hot_groups dictionary
    for group, columns in one_hot_groups.items():
        if any(column.startswith(prefix) for prefix in columns):
            # Add column to be dropped to the list
            columns_to_drop.append(column)

# Drop the encoded columns
Globals.cases_and_labels_df.drop(columns=columns_to_drop, inplace=True)

Globals.cases_and_labels_df.columns
# Out:
# Index(['case_id', 'source', 'release', 'year', 'age_group', 'sex_at_birth',
#        'fitzpatrick_skin_type', 'related_category', 'condition_duration',
#        'image_1_path', 'image_2_path', 'image_3_path', 'image_1_shot_type',
#        'image_2_shot_type', 'image_3_shot_type', 'combined_race',
#        'race_ethnicity_two_or_more_after_mitigation',
#        'dermatologist_gradable_for_skin_condition_1',
#        'dermatologist_gradable_for_skin_condition_2',
#        'dermatologist_gradable_for_skin_condition_3',
#        'dermatologist_skin_condition_on_label_name',
#        'dermatologist_skin_condition_confidence',
#        'weighted_skin_condition_label',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_1',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_2',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_3',
#        'dermatologist_fitzpatrick_skin_type_label_1',
#        'dermatologist_fitzpatrick_skin_type_label_2',
#        'dermatologist_fitzpatrick_skin_type_label_3',
#        'gradable_for_monk_skin_tone_india', 'gradable_for_monk_skin_tone_us',
#        'monk_skin_tone_label_india', 'monk_skin_tone_label_us',
#        'race_ethnicity', 'textures', 'body_parts', 'condition_symptoms',
#        'other_symptoms'],
#       dtype='object')

# %%
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', None)
Globals.cases_and_labels_df.sample(20)
# Out:
#                    case_id source release  year     age_group  \
# 2694   1536558571491805560   SCIN   1.0.0  2023  AGE_18_TO_29
# 2304  -8542064986886426986   SCIN   1.0.0  2023   AGE_UNKNOWN
# 3088    282923208361277809   SCIN   1.0.0  2023   AGE_UNKNOWN
# 105   -1352892938664792412   SCIN   1.0.0  2023   AGE_UNKNOWN
# 1554  -6110101408648949573   SCIN   1.0.0  2023   AGE_UNKNOWN
# 2765   1758257439672934702   SCIN   1.0.0  2023  AGE_18_TO_29
# 193   -1616454963494052359   SCIN   1.0.0  2023   AGE_UNKNOWN
# 4634   8040879229476600711   SCIN   1.0.0  2023   AGE_UNKNOWN
# 2120  -7947521871009771293   SCIN   1.0.0  2023  AGE_30_TO_39
# 1118  -4694867217250934182   SCIN   1.0.0  2023   AGE_UNKNOWN
# 556   -2800564846736956276   SCIN   1.0.0  2023  AGE_50_TO_59
# 2270  -8385554111491399495   SCIN   1.0.0  2023  AGE_30_TO_39
# 3863   5475014386524307360   SCIN   1.0.0  2023  AGE_40_TO_49
# 2903   2243877199469466472   SCIN   1.0.0  2023  AGE_30_TO_39
# 553   -2786042603621025019   SCIN   1.0.0  2023  AGE_40_TO_49
# 1073  -4550841138827406706   SCIN   1.0.0  2023  AGE_50_TO_59
# 1024   -439328432083694595   SCIN   1.0.0  2023  AGE_50_TO_59
# 4796   8541067645190369594   SCIN   1.0.0  2023  AGE_18_TO_29
# 3615   4672738659468200010   SCIN   1.0.0  2023   AGE_UNKNOWN
# 2242  -8315035996808813985   SCIN   1.0.0  2023  AGE_18_TO_29
#
#               sex_at_birth fitzpatrick_skin_type         related_category  \
# 2694                FEMALE                  FST3                      NaN
# 2304                  MALE                  FST2                     RASH
# 3088  OTHER_OR_UNSPECIFIED                   NaN                      NaN
# 105   OTHER_OR_UNSPECIFIED                   NaN                      NaN
# 1554  OTHER_OR_UNSPECIFIED                   NaN                     RASH
# 2765                  MALE                  FST4  OTHER_ISSUE_DESCRIPTION
# 193   OTHER_OR_UNSPECIFIED                   NaN                      NaN
# 4634  OTHER_OR_UNSPECIFIED                   NaN                     RASH
# 2120                  MALE                  FST3                     RASH
# 1118  OTHER_OR_UNSPECIFIED                   NaN                     RASH
# 556                   MALE                   NaN                     RASH
# 2270                  MALE                  FST5                     RASH
# 3863                FEMALE       NONE_IDENTIFIED                     RASH
# 2903                FEMALE                  FST3                      NaN
# 553                   MALE                  FST1                     RASH
# 1073                FEMALE                  FST3                     RASH
# 1024                  MALE                  FST5                     RASH
# 4796                  MALE                  FST6            LOOKS_HEALTHY
# 3615  OTHER_OR_UNSPECIFIED                   NaN                      NaN
# 2242                FEMALE                  FST4                     RASH
#
#           condition_duration                             image_1_path  \
# 2694                     NaN  dataset/images/-8222627480578524710.png
# 2304      LESS_THAN_ONE_WEEK  dataset/images/-3555487255426017347.png
# 3088                     NaN    dataset/images/125607177245589668.png
# 105                      NaN  dataset/images/-4176773000953294276.png
# 1554       ONE_TO_FOUR_WEEKS  dataset/images/-8406319565890157390.png
# 2765                 ONE_DAY  dataset/images/-4529991254357700468.png
# 193                      NaN  dataset/images/-7632127675025789395.png
# 4634                 ONE_DAY  dataset/images/-1221762902118367479.png
# 2120      LESS_THAN_ONE_WEEK  dataset/images/-7212343154996078392.png
# 1118                     NaN  dataset/images/-4275123751584001706.png
# 556       LESS_THAN_ONE_WEEK  dataset/images/-1479241597889930096.png
# 2270     ONE_TO_THREE_MONTHS  dataset/images/-3657414579240204642.png
# 3863     ONE_TO_THREE_MONTHS   dataset/images/6945764380486174282.png
# 2903  THREE_TO_TWELVE_MONTHS  dataset/images/-8522689401773516601.png
# 553       LESS_THAN_ONE_WEEK  dataset/images/-4320229049572975490.png
# 1073       ONE_TO_FOUR_WEEKS  dataset/images/-6326008063809357153.png
# 1024      LESS_THAN_ONE_WEEK   dataset/images/5065382152382630527.png
# 4796      LESS_THAN_ONE_WEEK  dataset/images/-5741761731606242043.png
# 3615                     NaN   dataset/images/7326001533582225037.png
# 2242                 ONE_DAY   dataset/images/4539450615054414408.png
#
#                                  image_2_path  \
# 2694   dataset/images/7772443988445294086.png
# 2304   dataset/images/3252880636526484617.png
# 3088                                      NaN
# 105   dataset/images/-7720050350557497359.png
# 1554   dataset/images/6641468760354802566.png
# 2765  dataset/images/-5967112197414294154.png
# 193    dataset/images/4769325170365798760.png
# 4634  dataset/images/-1870354016732256769.png
# 2120                                      NaN
# 1118                                      NaN
# 556   dataset/images/-1577483679207668274.png
# 2270                                      NaN
# 3863                                      NaN
# 2903                                      NaN
# 553    dataset/images/-958397637891782129.png
# 1073    dataset/images/144679265822215422.png
# 1024                                      NaN
# 4796   dataset/images/2888487846826334318.png
# 3615                                      NaN
# 2242                                      NaN
#
#                                  image_3_path image_1_shot_type  \
# 2694                                      NaN       AT_AN_ANGLE
# 2304   dataset/images/8215374641081279021.png       AT_AN_ANGLE
# 3088                                      NaN          CLOSE_UP
# 105    dataset/images/5864091977006975234.png       AT_DISTANCE
# 1554   dataset/images/7110316403206851010.png       AT_DISTANCE
# 2765  dataset/images/-8020442735008845217.png       AT_AN_ANGLE
# 193    dataset/images/5241006123467003866.png       AT_DISTANCE
# 4634                                      NaN       AT_AN_ANGLE
# 2120                                      NaN          CLOSE_UP
# 1118                                      NaN          CLOSE_UP
# 556   dataset/images/-8973154077446727444.png          CLOSE_UP
# 2270                                      NaN          CLOSE_UP
# 3863                                      NaN          CLOSE_UP
# 2903                                      NaN          CLOSE_UP
# 553                                       NaN          CLOSE_UP
# 1073                                      NaN          CLOSE_UP
# 1024                                      NaN          CLOSE_UP
# 4796   dataset/images/4972611748902990497.png          CLOSE_UP
# 3615                                      NaN          CLOSE_UP
# 2242                                      NaN          CLOSE_UP
#
#      image_2_shot_type image_3_shot_type  \
# 2694          CLOSE_UP               NaN
# 2304       AT_DISTANCE          CLOSE_UP
# 3088               NaN               NaN
# 105           CLOSE_UP       AT_AN_ANGLE
# 1554       AT_AN_ANGLE          CLOSE_UP
# 2765          CLOSE_UP       AT_DISTANCE
# 193        AT_AN_ANGLE          CLOSE_UP
# 4634          CLOSE_UP               NaN
# 2120               NaN               NaN
# 1118               NaN               NaN
# 556        AT_DISTANCE       AT_AN_ANGLE
# 2270               NaN               NaN
# 3863               NaN               NaN
# 2903               NaN               NaN
# 553        AT_AN_ANGLE               NaN
# 1073       AT_AN_ANGLE               NaN
# 1024               NaN               NaN
# 4796       AT_AN_ANGLE       AT_DISTANCE
# 3615               NaN               NaN
# 2242               NaN               NaN
#
#                                 combined_race  \
# 2694                     PREFER_NOT_TO_ANSWER
# 2304  HISPANIC_LATINO_OR_SPANISH_ORIGIN,WHITE
# 3088                                      NaN
# 105                                       NaN
# 1554                                      NaN
# 2765                                    WHITE
# 193                                       NaN
# 4634                                      NaN
# 2120                                    WHITE
# 1118                                      NaN
# 556                                     WHITE
# 2270        HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 3863                                    WHITE
# 2903                                    WHITE
# 553                                     WHITE
# 1073                                    WHITE
# 1024                                    WHITE
# 4796                BLACK_OR_AFRICAN_AMERICAN
# 3615                                      NaN
# 2242                BLACK_OR_AFRICAN_AMERICAN
#
#      race_ethnicity_two_or_more_after_mitigation  \
# 2694                                         NaN
# 2304                                         NaN
# 3088                                         NaN
# 105                                          NaN
# 1554                                         NaN
# 2765                                         NaN
# 193                                          NaN
# 4634                                         NaN
# 2120                                         NaN
# 1118                                         NaN
# 556                                          NaN
# 2270                                         NaN
# 3863                                         NaN
# 2903                                         NaN
# 553                                          NaN
# 1073                                         NaN
# 1024                                         NaN
# 4796                                         NaN
# 3615                                         NaN
# 2242                                         NaN
#
#      dermatologist_gradable_for_skin_condition_1  \
# 2694               NO_IMAGE_QUALITY_INSUFFICIENT
# 2304        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 3088               NO_IMAGE_QUALITY_INSUFFICIENT
# 105                NO_IMAGE_QUALITY_INSUFFICIENT
# 1554        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2765               NO_IMAGE_QUALITY_INSUFFICIENT
# 193         DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 4634        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2120               NO_IMAGE_QUALITY_INSUFFICIENT
# 1118               NO_IMAGE_QUALITY_INSUFFICIENT
# 556                NO_IMAGE_QUALITY_INSUFFICIENT
# 2270        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 3863        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2903        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 553         DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 1073        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 1024               NO_IMAGE_QUALITY_INSUFFICIENT
# 4796               NO_IMAGE_QUALITY_INSUFFICIENT
# 3615               NO_IMAGE_QUALITY_INSUFFICIENT
# 2242        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#      dermatologist_gradable_for_skin_condition_2  \
# 2694                                         NaN
# 2304        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 3088                                         NaN
# 105                                          NaN
# 1554                                         NaN
# 2765                                         NaN
# 193                                          NaN
# 4634                                         NaN
# 2120                                         NaN
# 1118                                         NaN
# 556                                          NaN
# 2270                                         NaN
# 3863                                         NaN
# 2903                                         NaN
# 553                                          NaN
# 1073                                         NaN
# 1024                                         NaN
# 4796               NO_IMAGE_QUALITY_INSUFFICIENT
# 3615                                         NaN
# 2242                                         NaN
#
#      dermatologist_gradable_for_skin_condition_3  \
# 2694                                         NaN
# 2304               NO_IMAGE_QUALITY_INSUFFICIENT
# 3088                                         NaN
# 105                                          NaN
# 1554                                         NaN
# 2765                                         NaN
# 193                                          NaN
# 4634                                         NaN
# 2120                                         NaN
# 1118                                         NaN
# 556                                          NaN
# 2270                                         NaN
# 3863                                         NaN
# 2903                                         NaN
# 553                                          NaN
# 1073                                         NaN
# 1024                                         NaN
# 4796               NO_IMAGE_QUALITY_INSUFFICIENT
# 3615                                         NaN
# 2242                                         NaN
#
#              dermatologist_skin_condition_on_label_name  \
# 2694                                                 []
# 2304       ['Urticaria', 'Allergic Contact Dermatitis']
# 3088                                                 []
# 105                                                  []
# 1554  ['Impetigo', 'Psoriasis', 'Seborrheic Dermatit...
# 2765                                                 []
# 193   ['Eczema', 'Lichen planus/lichenoid eruption',...
# 4634                            ['Erythema multiforme']
# 2120                                                 []
# 1118                                                 []
# 556                                                  []
# 2270  ['Pityriasis rosea', 'Eczema', 'Lichen planus/...
# 3863                                         ['Eczema']
# 2903  ['Viral Exanthem', 'Erythema multiforme', 'Syp...
# 553   ['Traumatic petechiae', 'Allergic Contact Derm...
# 1073  ['Tinea', 'Eczema', 'Allergic Contact Dermatit...
# 1024                                                 []
# 4796                                                 []
# 3615                                                 []
# 2242  ['Allergic Contact Dermatitis', 'Irritant Cont...
#
#      dermatologist_skin_condition_confidence  \
# 2694                                      []
# 2304                                  [3, 1]
# 3088                                      []
# 105                                       []
# 1554                               [1, 1, 4]
# 2765                                      []
# 193                                [1, 2, 1]
# 4634                                     [5]
# 2120                                      []
# 1118                                      []
# 556                                       []
# 2270                               [5, 3, 3]
# 3863                                     [5]
# 2903                               [1, 1, 1]
# 553                                [1, 1, 1]
# 1073                               [1, 1, 5]
# 1024                                      []
# 4796                                      []
# 3615                                      []
# 2242                                  [3, 2]
#
#                           weighted_skin_condition_label  \
# 2694                                                 {}
# 2304  {'Urticaria': 0.67, 'Allergic Contact Dermatit...
# 3088                                                 {}
# 105                                                  {}
# 1554  {'Seborrheic Dermatitis': 0.55, 'Impetigo': 0....
# 2765                                                 {}
# 193   {'Lichen planus/lichenoid eruption': 0.55, 'Ec...
# 4634                       {'Erythema multiforme': 1.0}
# 2120                                                 {}
# 1118                                                 {}
# 556                                                  {}
# 2270  {'Pityriasis rosea': 0.55, 'Eczema': 0.23, 'Li...
# 3863                                    {'Eczema': 1.0}
# 2903  {'Viral Exanthem': 0.33, 'Erythema multiforme'...
# 553   {'Traumatic petechiae': 0.33, 'Allergic Contac...
# 1073  {'Allergic Contact Dermatitis': 0.55, 'Tinea':...
# 1024                                                 {}
# 4796                                                 {}
# 3615                                                 {}
# 2242  {'Allergic Contact Dermatitis': 0.67, 'Irritan...
#
#      dermatologist_gradable_for_fitzpatrick_skin_type_1  \
# 2694                                                YES
# 2304                                                YES
# 3088                                                YES
# 105                                                 YES
# 1554                                                YES
# 2765                                                 NO
# 193                                                 YES
# 4634                                                YES
# 2120                                                 NO
# 1118                                                YES
# 556                                                  NO
# 2270                                                YES
# 3863                                                YES
# 2903                                                YES
# 553                                                 YES
# 1073                                                YES
# 1024                                                YES
# 4796                                                 NO
# 3615                                                YES
# 2242                                                YES
#
#      dermatologist_gradable_for_fitzpatrick_skin_type_2  \
# 2694                                                NaN
# 2304                                                YES
# 3088                                                NaN
# 105                                                 NaN
# 1554                                                NaN
# 2765                                                NaN
# 193                                                 NaN
# 4634                                                NaN
# 2120                                                NaN
# 1118                                                NaN
# 556                                                 NaN
# 2270                                                NaN
# 3863                                                NaN
# 2903                                                NaN
# 553                                                 NaN
# 1073                                                NaN
# 1024                                                NaN
# 4796                                                 NO
# 3615                                                NaN
# 2242                                                NaN
#
#      dermatologist_gradable_for_fitzpatrick_skin_type_3  \
# 2694                                                NaN
# 2304                                                YES
# 3088                                                NaN
# 105                                                 NaN
# 1554                                                NaN
# 2765                                                NaN
# 193                                                 NaN
# 4634                                                NaN
# 2120                                                NaN
# 1118                                                NaN
# 556                                                 NaN
# 2270                                                NaN
# 3863                                                NaN
# 2903                                                NaN
# 553                                                 NaN
# 1073                                                NaN
# 1024                                                NaN
# 4796                                                 NO
# 3615                                                NaN
# 2242                                                NaN
#
#      dermatologist_fitzpatrick_skin_type_label_1  \
# 2694                                        FST2
# 2304                                        FST2
# 3088                                        FST3
# 105                                         FST4
# 1554                                        FST1
# 2765                                         NaN
# 193                                         FST3
# 4634                                        FST5
# 2120                                         NaN
# 1118                                        FST3
# 556                                          NaN
# 2270                                        FST2
# 3863                                        FST3
# 2903                                        FST4
# 553                                         FST1
# 1073                                        FST3
# 1024                                        FST3
# 4796                                         NaN
# 3615                                        FST3
# 2242                                        FST3
#
#      dermatologist_fitzpatrick_skin_type_label_2  \
# 2694                                         NaN
# 2304                                        FST1
# 3088                                         NaN
# 105                                          NaN
# 1554                                         NaN
# 2765                                         NaN
# 193                                          NaN
# 4634                                         NaN
# 2120                                         NaN
# 1118                                         NaN
# 556                                          NaN
# 2270                                         NaN
# 3863                                         NaN
# 2903                                         NaN
# 553                                          NaN
# 1073                                         NaN
# 1024                                         NaN
# 4796                                         NaN
# 3615                                         NaN
# 2242                                         NaN
#
#      dermatologist_fitzpatrick_skin_type_label_3  \
# 2694                                         NaN
# 2304                                        FST2
# 3088                                         NaN
# 105                                          NaN
# 1554                                         NaN
# 2765                                         NaN
# 193                                          NaN
# 4634                                         NaN
# 2120                                         NaN
# 1118                                         NaN
# 556                                          NaN
# 2270                                         NaN
# 3863                                         NaN
# 2903                                         NaN
# 553                                          NaN
# 1073                                         NaN
# 1024                                         NaN
# 4796                                         NaN
# 3615                                         NaN
# 2242                                         NaN
#
#      gradable_for_monk_skin_tone_india gradable_for_monk_skin_tone_us  \
# 2694                              True                           True
# 2304                              True                           True
# 3088                              True                           True
# 105                               True                           True
# 1554                              True                           True
# 2765                              True                           True
# 193                               True                           True
# 4634                              True                           True
# 2120                              True                           True
# 1118                              True                           True
# 556                               True                           True
# 2270                              True                           True
# 3863                              True                           True
# 2903                              True                           True
# 553                               True                           True
# 1073                              True                           True
# 1024                              True                           True
# 4796                              True                          False
# 3615                              True                           True
# 2242                              True                           True
#
#       monk_skin_tone_label_india  monk_skin_tone_label_us  \
# 2694                         2.0                      2.0
# 2304                         2.0                      1.0
# 3088                         4.0                      3.0
# 105                          3.0                      5.0
# 1554                         2.0                      2.0
# 2765                         1.0                      1.0
# 193                          3.0                      4.0
# 4634                         4.0                      7.0
# 2120                         4.0                      4.0
# 1118                         2.0                      3.0
# 556                          2.0                      3.0
# 2270                         3.0                      3.0
# 3863                         2.0                      3.0
# 2903                         2.0                      4.0
# 553                          2.0                      2.0
# 1073                         2.0                      3.0
# 1024                         2.0                      1.0
# 4796                         4.0                      NaN
# 3615                         3.0                      4.0
# 2242                         2.0                      1.0
#
#                                         race_ethnicity  \
# 2694               race_ethnicity_prefer_not_to_answer
# 2304                              race_ethnicity_white
# 3088
# 105
# 1554
# 2765                              race_ethnicity_white
# 193
# 4634
# 2120                              race_ethnicity_white
# 1118
# 556                               race_ethnicity_white
# 2270  race_ethnicity_hispanic_latino_or_spanish_origin
# 3863                              race_ethnicity_white
# 2903                              race_ethnicity_white
# 553                               race_ethnicity_white
# 1073                              race_ethnicity_white
# 1024                              race_ethnicity_white
# 4796          race_ethnicity_black_or_african_american
# 3615
# 2242          race_ethnicity_black_or_african_american
#
#                       textures               body_parts  \
# 2694
# 2304             textures_flat           body_parts_leg
# 3088
# 105      textures_fluid_filled
# 1554   textures_rough_or_flaky  body_parts_head_or_neck
# 2765     textures_fluid_filled
# 193
# 4634   textures_rough_or_flaky         body_parts_other
# 2120     textures_fluid_filled    body_parts_torso_back
# 1118  textures_raised_or_bumpy           body_parts_leg
# 556   textures_raised_or_bumpy  body_parts_back_of_hand
# 2270             textures_flat   body_parts_torso_front
# 3863   textures_rough_or_flaky    body_parts_torso_back
# 2903     textures_fluid_filled     body_parts_foot_sole
# 553                                      body_parts_leg
# 1073   textures_rough_or_flaky           body_parts_arm
# 1024             textures_flat           body_parts_leg
# 4796   textures_rough_or_flaky         body_parts_other
# 3615  textures_raised_or_bumpy      body_parts_buttocks
# 2242  textures_raised_or_bumpy           body_parts_arm
#
#                              condition_symptoms  \
# 2694                 condition_symptoms_burning
# 2304                 condition_symptoms_burning
# 3088
# 105
# 1554
# 2765                    condition_symptoms_pain
# 193
# 4634               condition_symptoms_darkening
# 2120                    condition_symptoms_pain
# 1118                 condition_symptoms_itching
# 556                     condition_symptoms_pain
# 2270  condition_symptoms_no_relevant_experience
# 3863                    condition_symptoms_pain
# 2903                    condition_symptoms_pain
# 553    condition_symptoms_bothersome_appearance
# 1073                 condition_symptoms_burning
# 1024         condition_symptoms_increasing_size
# 4796                    condition_symptoms_pain
# 3615                 condition_symptoms_itching
# 2242                    condition_symptoms_pain
#
#                            other_symptoms
# 2694  other_symptoms_no_relevant_symptoms
# 2304  other_symptoms_no_relevant_symptoms
# 3088
# 105
# 1554
# 2765           other_symptoms_mouth_sores
# 193
# 4634
# 2120  other_symptoms_no_relevant_symptoms
# 1118  other_symptoms_no_relevant_symptoms
# 556             other_symptoms_joint_pain
# 2270  other_symptoms_no_relevant_symptoms
# 3863  other_symptoms_no_relevant_symptoms
# 2903            other_symptoms_joint_pain
# 553   other_symptoms_no_relevant_symptoms
# 1073  other_symptoms_no_relevant_symptoms
# 1024               other_symptoms_fatigue
# 4796  other_symptoms_no_relevant_symptoms
# 3615  other_symptoms_no_relevant_symptoms
# 2242  other_symptoms_no_relevant_symptoms

# %%
Globals.cases_and_labels_df.columns.value_counts().sum()
# Out:
# 38

# %%
Globals.cases_and_labels_df.columns
# Out:
# Index(['case_id', 'source', 'release', 'year', 'age_group', 'sex_at_birth',
#        'fitzpatrick_skin_type', 'related_category', 'condition_duration',
#        'image_1_path', 'image_2_path', 'image_3_path', 'image_1_shot_type',
#        'image_2_shot_type', 'image_3_shot_type', 'combined_race',
#        'race_ethnicity_two_or_more_after_mitigation',
#        'dermatologist_gradable_for_skin_condition_1',
#        'dermatologist_gradable_for_skin_condition_2',
#        'dermatologist_gradable_for_skin_condition_3',
#        'dermatologist_skin_condition_on_label_name',
#        'dermatologist_skin_condition_confidence',
#        'weighted_skin_condition_label',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_1',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_2',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_3',
#        'dermatologist_fitzpatrick_skin_type_label_1',
#        'dermatologist_fitzpatrick_skin_type_label_2',
#        'dermatologist_fitzpatrick_skin_type_label_3',
#        'gradable_for_monk_skin_tone_india', 'gradable_for_monk_skin_tone_us',
#        'monk_skin_tone_label_india', 'monk_skin_tone_label_us',
#        'race_ethnicity', 'textures', 'body_parts', 'condition_symptoms',
#        'other_symptoms'],
#       dtype='object')

# %%
df = Globals.cases_and_labels_df
df.info()

# Missing columns
"""
fitzpatrick_skin_type 2503
related_category 3779
condition_duration 4036
image_3_path != image_3_shot_type
combined_race 2652
race_ethnicity_two_or_more_after_mitigation 83
dermatologist_fitzpatrick_skin_type_label_1 4302
gradable_for_monk_skin_tone_india  5023
gradable_for_monk_skin_tone_us 5023
monk_skin_tone_label_india 5019
monk_skin_tone_label_us 5005
"""

# unbalaced columns : Drop or Fix?
"""
fitzpatrick_skin_type
combined_race
race_ethnicity_two_or_more_after_mitigation
"""
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5033 entries, 0 to 5032
# Data columns (total 38 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   case_id                                             5033 non-null   object
#  1   source                                              5033 non-null   object
#  2   release                                             5033 non-null   object
#  3   year                                                5033 non-null   int64
#  4   age_group                                           5032 non-null   object
#  5   sex_at_birth                                        5032 non-null   object
#  6   fitzpatrick_skin_type                               2503 non-null   object
#  7   related_category                                    3779 non-null   object
#  8   condition_duration                                  4036 non-null   object
#  9   image_1_path                                        5033 non-null   object
#  10  image_2_path                                        3085 non-null   object
#  11  image_3_path                                        2289 non-null   object
#  12  image_1_shot_type                                   5033 non-null   object
#  13  image_2_shot_type                                   3085 non-null   object
#  14  image_3_shot_type                                   2290 non-null   object
#  15  combined_race                                       2652 non-null   object
#  16  race_ethnicity_two_or_more_after_mitigation         83 non-null     object
#  17  dermatologist_gradable_for_skin_condition_1         5033 non-null   object
#  18  dermatologist_gradable_for_skin_condition_2         716 non-null    object
#  19  dermatologist_gradable_for_skin_condition_3         716 non-null    object
#  20  dermatologist_skin_condition_on_label_name          5033 non-null   object
#  21  dermatologist_skin_condition_confidence             5033 non-null   object
#  22  weighted_skin_condition_label                       5033 non-null   object
#  23  dermatologist_gradable_for_fitzpatrick_skin_type_1  5033 non-null   object
#  24  dermatologist_gradable_for_fitzpatrick_skin_type_2  716 non-null    object
#  25  dermatologist_gradable_for_fitzpatrick_skin_type_3  716 non-null    object
#  26  dermatologist_fitzpatrick_skin_type_label_1         4302 non-null   object
#  27  dermatologist_fitzpatrick_skin_type_label_2         634 non-null    object
#  28  dermatologist_fitzpatrick_skin_type_label_3         631 non-null    object
#  29  gradable_for_monk_skin_tone_india                   5023 non-null   object
#  30  gradable_for_monk_skin_tone_us                      5023 non-null   object
#  31  monk_skin_tone_label_india                          5019 non-null   float64
#  32  monk_skin_tone_label_us                             5005 non-null   float64
#  33  race_ethnicity                                      5033 non-null   object
#  34  textures                                            5033 non-null   object
#  35  body_parts                                          5033 non-null   object
#  36  condition_symptoms                                  5033 non-null   object
#  37  other_symptoms                                      5033 non-null   object
# dtypes: float64(2), int64(1), object(35)
# memory usage: 1.5+ MB
# '\nfitzpatrick_skin_type\ncombined_race\nrace_ethnicity_two_or_more_after_mitigation\n'

# %%
import pandas as pd

# Assuming df is your DataFrame
# Example: df = pd.read_csv('your_data.csv')

columns = {
    'fitzpatrick_skin_type': 2503,
    'related_category': 3779,
    'condition_duration': 4036,
    'combined_race': 2652,
    'race_ethnicity_two_or_more_after_mitigation': 83,
    'dermatologist_fitzpatrick_skin_type_label': 4370,
    'gradable_for_monk_skin_tone_india': 5023,
    'gradable_for_monk_skin_tone_us': 5023,
    'monk_skin_tone_label_india': 5019,
    'monk_skin_tone_label_us': 5005
}

for column, expected_sum in columns.items():
    if column in df.columns:
        value_counts = df[column].value_counts()
        actual_sum = value_counts.sum()
        print(f"{column}:")
        print(value_counts)
        print(f"Sum of values: {actual_sum} (Expected: {expected_sum})\n")
    else:
        print(f"Column '{column}' does not exist in the dataframe.\n")
# Out:
# fitzpatrick_skin_type:
# fitzpatrick_skin_type
# FST3               661
# FST2               542
# FST4               427
# NONE_IDENTIFIED    328
# FST5               214
# FST1               188
# FST6               143
# Name: count, dtype: int64
# Sum of values: 2503 (Expected: 2503)
#
# related_category:
# related_category
# RASH                       2876
# OTHER_ISSUE_DESCRIPTION     414
# LOOKS_HEALTHY               290
# ACNE                         74
# GROWTH_OR_MOLE               45
# PIGMENTARY_PROBLEM           37
# NAIL_PROBLEM                 20
# OTHER_HAIR_PROBLEM           12
# HAIR_LOSS                    11
# Name: count, dtype: int64
# Sum of values: 3779 (Expected: 3779)
#
# condition_duration:
# condition_duration
# LESS_THAN_ONE_WEEK        1386
# ONE_TO_FOUR_WEEKS          960
# ONE_DAY                    784
# ONE_TO_THREE_MONTHS        318
# THREE_TO_TWELVE_MONTHS     237
# MORE_THAN_ONE_YEAR         201
# MORE_THAN_FIVE_YEARS        91
# UNKNOWN                     39
# SINCE_CHILDHOOD             20
# Name: count, dtype: int64
# Sum of values: 4036 (Expected: 4036)
#
# combined_race:
# combined_race
# WHITE                                                          1762
# BLACK_OR_AFRICAN_AMERICAN                                       267
# HISPANIC_LATINO_OR_SPANISH_ORIGIN                               224
# ASIAN                                                            85
# TWO_OR_MORE_AFTER_MITIGATION                                     83
# HISPANIC_LATINO_OR_SPANISH_ORIGIN,WHITE                          55
# AMERICAN_INDIAN_OR_ALASKA_NATIVE                                 48
# PREFER_NOT_TO_ANSWER                                             34
# AMERICAN_INDIAN_OR_ALASKA_NATIVE,WHITE                           25
# BLACK_OR_AFRICAN_AMERICAN,WHITE                                  20
# OTHER_RACE                                                       16
# BLACK_OR_AFRICAN_AMERICAN,HISPANIC_LATINO_OR_SPANISH_ORIGIN      11
# ASIAN,WHITE                                                      11
# MIDDLE_EASTERN_OR_NORTH_AFRICAN                                   7
# NATIVE_HAWAIIAN_OR_PACIFIC_ISLANDER                               4
# Name: count, dtype: int64
# Sum of values: 2652 (Expected: 2652)
#
# race_ethnicity_two_or_more_after_mitigation:
# race_ethnicity_two_or_more_after_mitigation
# YES    83
# Name: count, dtype: int64
# Sum of values: 83 (Expected: 83)
#
# Column 'dermatologist_fitzpatrick_skin_type_label' does not exist in the dataframe.
#
# gradable_for_monk_skin_tone_india:
# gradable_for_monk_skin_tone_india
# True     5019
# False       4
# Name: count, dtype: int64
# Sum of values: 5023 (Expected: 5023)
#
# gradable_for_monk_skin_tone_us:
# gradable_for_monk_skin_tone_us
# True     5005
# False      18
# Name: count, dtype: int64
# Sum of values: 5023 (Expected: 5023)
#
# monk_skin_tone_label_india:
# monk_skin_tone_label_india
# 2.0    2427
# 3.0    1591
# 4.0     522
# 1.0     187
# 5.0     177
# 6.0      63
# 7.0      35
# 8.0      14
# 9.0       3
# Name: count, dtype: int64
# Sum of values: 5019 (Expected: 5019)
#
# monk_skin_tone_label_us:
# monk_skin_tone_label_us
# 2.0     1660
# 3.0     1265
# 4.0      687
# 1.0      577
# 5.0      361
# 6.0      248
# 7.0      137
# 8.0       57
# 9.0       11
# 10.0       2
# Name: count, dtype: int64
# Sum of values: 5005 (Expected: 5005)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5033 entries, 0 to 5032
# Data columns (total 38 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   case_id                                             5033 non-null   object
#  1   source                                              5033 non-null   object
#  2   release                                             5033 non-null   object
#  3   year                                                5033 non-null   int64
#  4   age_group                                           5032 non-null   object
#  5   sex_at_birth                                        5032 non-null   object
#  6   fitzpatrick_skin_type                               2503 non-null   object
#  7   related_category                                    3779 non-null   object
#  8   condition_duration                                  4036 non-null   object
#  9   image_1_path                                        5033 non-null   object
#  10  image_2_path                                        3085 non-null   object
#  11  image_3_path                                        2289 non-null   object
#  12  image_1_shot_type                                   5033 non-null   object
#  13  image_2_shot_type                                   3085 non-null   object
#  14  image_3_shot_type                                   2290 non-null   object
#  15  combined_race                                       2652 non-null   object
#  16  race_ethnicity_two_or_more_after_mitigation         83 non-null     object
#  17  dermatologist_gradable_for_skin_condition_1         5033 non-null   object
#  18  dermatologist_gradable_for_skin_condition_2         716 non-null    object
#  19  dermatologist_gradable_for_skin_condition_3         716 non-null    object
#  20  dermatologist_skin_condition_on_label_name          5033 non-null   object
#  21  dermatologist_skin_condition_confidence             5033 non-null   object
#  22  weighted_skin_condition_label                       5033 non-null   object
#  23  dermatologist_gradable_for_fitzpatrick_skin_type_1  5033 non-null   object
#  24  dermatologist_gradable_for_fitzpatrick_skin_type_2  716 non-null    object
#  25  dermatologist_gradable_for_fitzpatrick_skin_type_3  716 non-null    object
#  26  dermatologist_fitzpatrick_skin_type_label_1         4302 non-null   object
#  27  dermatologist_fitzpatrick_skin_type_label_2         634 non-null    object
#  28  dermatologist_fitzpatrick_skin_type_label_3         631 non-null    object
#  29  gradable_for_monk_skin_tone_india                   5023 non-null   object
#  30  gradable_for_monk_skin_tone_us                      5023 non-null   object
#  31  monk_skin_tone_label_india                          5019 non-null   float64
#  32  monk_skin_tone_label_us                             5005 non-null   float64
#  33  race_ethnicity                                      5033 non-null   object
#  34  textures                                            5033 non-null   object
#  35  body_parts                                          5033 non-null   object
#  36  condition_symptoms                                  5033 non-null   object
#  37  other_symptoms                                      5033 non-null   object
# dtypes: float64(2), int64(1), object(35)
# memory usage: 1.5+ MB

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>7.Feature Engineering </b></h1>
# </div>

# %%
gradable_columns1 = ['dermatologist_gradable_for_skin_condition_1',
                     'dermatologist_gradable_for_skin_condition_2',
                     'dermatologist_gradable_for_skin_condition_3']

gradable_columns2 = ['dermatologist_gradable_for_fitzpatrick_skin_type_1',
                     'dermatologist_gradable_for_fitzpatrick_skin_type_2', # fixed typo
                     'dermatologist_gradable_for_fitzpatrick_skin_type_3'] # fixed typo

gradable_columns3 = ['dermatologist_fitzpatrick_skin_type_label_1',
                     'dermatologist_fitzpatrick_skin_type_label_2',
                     'dermatologist_fitzpatrick_skin_type_label_3']

# Function to calculate the mode for each row
def calculate_mode(row):
    return row.mode().iloc[0] if not row.mode().empty else None

# Apply the mode calculation for each set of columns
df['dermatologist_gradable_for_skin_condition_1'] = df[gradable_columns1].apply(calculate_mode, axis=1)
df['dermatologist_gradable_for_fitzpatrick_skin_type_1'] = df[gradable_columns2].apply(calculate_mode, axis=1)
df['dermatologist_fitzpatrick_skin_type_label_1'] = df[gradable_columns3].apply(calculate_mode, axis=1)

# %%
df['dermatologist_gradable_for_skin_condition_1'].value_counts().sum()
# Out:
# 5033

# %%
df['dermatologist_gradable_for_fitzpatrick_skin_type_1'].value_counts().sum()
# Out:
# 5033

# %%
df['dermatologist_fitzpatrick_skin_type_label_1'].value_counts().sum()
# Out:
# 4370

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>8.Impute the Missing Values & Fix the Unbalanced Data </b></h1>
# </div>

# %% [markdown]
# ### Impute dermatologist_fitzpatrick_skin_type_label_1

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder

# Encode the categorical labels
le = LabelEncoder()
df['dermatologist_fitzpatrick_skin_type_label_1_encoded'] = le.fit_transform(df['dermatologist_fitzpatrick_skin_type_label_1'].astype(str))

# Impute missing values using the most frequent value strategy
imputer = SimpleImputer(strategy='most_frequent')
imputed_data = imputer.fit_transform(df[['dermatologist_fitzpatrick_skin_type_label_1_encoded']])

# Decode the imputed values back to the original labels
df['dermatologist_fitzpatrick_skin_type_label_1_imputed'] = le.inverse_transform(imputed_data.astype(int).ravel())

# %%
df['dermatologist_fitzpatrick_skin_type_label_1_imputed'].value_counts().sum()
# Out:
# 5033

# %%
df['dermatologist_fitzpatrick_skin_type_label'] = df['dermatologist_fitzpatrick_skin_type_label_1_imputed']
df.drop(['dermatologist_fitzpatrick_skin_type_label_1_imputed','dermatologist_fitzpatrick_skin_type_label_1_encoded'], axis =1,inplace = True)
df.columns
# Out:
# Index(['case_id', 'source', 'release', 'year', 'age_group', 'sex_at_birth',
#        'fitzpatrick_skin_type', 'related_category', 'condition_duration',
#        'image_1_path', 'image_2_path', 'image_3_path', 'image_1_shot_type',
#        'image_2_shot_type', 'image_3_shot_type', 'combined_race',
#        'race_ethnicity_two_or_more_after_mitigation',
#        'dermatologist_gradable_for_skin_condition_1',
#        'dermatologist_gradable_for_skin_condition_2',
#        'dermatologist_gradable_for_skin_condition_3',
#        'dermatologist_skin_condition_on_label_name',
#        'dermatologist_skin_condition_confidence',
#        'weighted_skin_condition_label',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_1',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_2',
#        'dermatologist_gradable_for_fitzpatrick_skin_type_3',
#        'dermatologist_fitzpatrick_skin_type_label_1',
#        'dermatologist_fitzpatrick_skin_type_label_2',
#        'dermatologist_fitzpatrick_skin_type_label_3',
#        'gradable_for_monk_skin_tone_india', 'gradable_for_monk_skin_tone_us',
#        'monk_skin_tone_label_india', 'monk_skin_tone_label_us',
#        'race_ethnicity', 'textures', 'body_parts', 'condition_symptoms',
#        'other_symptoms', 'dermatologist_fitzpatrick_skin_type_label'],
#       dtype='object')

# %%
df['dermatologist_fitzpatrick_skin_type_label'] = df['dermatologist_fitzpatrick_skin_type_label'].replace('None', np.nan)

# %%
df['dermatologist_fitzpatrick_skin_type_label'].value_counts()
# Out:
# dermatologist_fitzpatrick_skin_type_label
# FST2    1491
# FST3    1351
# FST4     716
# FST1     381
# FST5     364
# FST6      67
# Name: count, dtype: int64

# %%
df['monk_skin_tone_label_us'].value_counts()
# Out:
# monk_skin_tone_label_us
# 2.0     1660
# 3.0     1265
# 4.0      687
# 1.0      577
# 5.0      361
# 6.0      248
# 7.0      137
# 8.0       57
# 9.0       11
# 10.0       2
# Name: count, dtype: int64

# %%
df['monk_skin_tone_label_india'].value_counts()
# Out:
# monk_skin_tone_label_india
# 2.0    2427
# 3.0    1591
# 4.0     522
# 1.0     187
# 5.0     177
# 6.0      63
# 7.0      35
# 8.0      14
# 9.0       3
# Name: count, dtype: int64

# %% [markdown]
# ### Impute monk skin tone

# %%
from sklearn.impute import SimpleImputer

# Define the imputer with strategy as 'most_frequent'
imputer = SimpleImputer(strategy='most_frequent')

# Impute missing values in 'monk_skin_tone_label_india'
df['monk_skin_tone_label_india'] = imputer.fit_transform(df[['monk_skin_tone_label_india']])

# Impute missing values in 'monk_skin_tone_label_us'
df['monk_skin_tone_label_us'] = imputer.fit_transform(df[['monk_skin_tone_label_us']])

# %%
df['dermatologist_fitzpatrick_skin_type_label'].value_counts()
# Out:
# dermatologist_fitzpatrick_skin_type_label
# FST2    1491
# FST3    1351
# FST4     716
# FST1     381
# FST5     364
# FST6      67
# Name: count, dtype: int64

# %% [markdown]
# ### We can Predict the missing values of Fitzpatrick from Monk skin tone scale

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame
# Encode the target variable
le = LabelEncoder()
df['dermatologist_fitzpatrick_skin_type_label_encoded'] = le.fit_transform(df['dermatologist_fitzpatrick_skin_type_label'].astype(str))

# Split the data into training and prediction sets
train_df = df.dropna(subset=['dermatologist_fitzpatrick_skin_type_label'])
predict_df = df[df['dermatologist_fitzpatrick_skin_type_label'].isnull()]

# Features and target variable for training
X_train = train_df[['monk_skin_tone_label_us', 'monk_skin_tone_label_india']]
y_train = train_df['dermatologist_fitzpatrick_skin_type_label_encoded']

# Features for prediction
X_predict = predict_df[['monk_skin_tone_label_us', 'monk_skin_tone_label_india']]

# Train the RandomForestClassifier
clf = RandomForestClassifier(random_state=42)
clf.fit(X_train, y_train)

# Predict the missing values
predictions = clf.predict(X_predict)

# Decode the predicted labels
predicted_labels = le.inverse_transform(predictions)

# Fill the missing values in the original DataFrame
df.loc[df['dermatologist_fitzpatrick_skin_type_label'].isnull(), 'dermatologist_fitzpatrick_skin_type_label'] = predicted_labels

# Drop the encoded target column as it is no longer needed
df.drop(columns=['dermatologist_fitzpatrick_skin_type_label_encoded'], inplace=True)

# %%
df['dermatologist_fitzpatrick_skin_type_label'].value_counts().sum()
# Out:
# 5033

# %% [markdown]
# ### Predict the missing values of gradable monk skin tone

# %%
# Importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_predict

# Selecting features and target variable
X_train = df.dropna(subset=['gradable_for_monk_skin_tone_us'])[['monk_skin_tone_label_us']]
y_train = df.dropna(subset=['gradable_for_monk_skin_tone_us'])['gradable_for_monk_skin_tone_us']

# Initializing and training the model
model = RandomForestRegressor(random_state=42)
predicted_values = cross_val_predict(model, X_train, y_train, cv=5)

# Predict missing values
missing_data_indices = df[df['gradable_for_monk_skin_tone_us'].isnull()].index
predicted_values_subset = predicted_values[:len(missing_data_indices)]

# Update DataFrame with predicted values
df.loc[missing_data_indices, 'gradable_for_monk_skin_tone_us'] = predicted_values_subset

# %%
# Importing necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_predict

# Selecting features and target variable
X_train = df.dropna(subset=['gradable_for_monk_skin_tone_india'])[['monk_skin_tone_label_india']]
y_train = df.dropna(subset=['gradable_for_monk_skin_tone_india'])['gradable_for_monk_skin_tone_india']

# Initializing and training the model
model = RandomForestRegressor(random_state=42)
predicted_values = cross_val_predict(model, X_train, y_train, cv=5)

# Predict missing values
missing_data_indices = df[df['gradable_for_monk_skin_tone_india'].isnull()].index
predicted_values_subset = predicted_values[:len(missing_data_indices)]

# Update DataFrame with predicted values
df.loc[missing_data_indices, 'gradable_for_monk_skin_tone_india'] = predicted_values_subset

# %% [markdown]
# ### Predict the combined race type from the fitzpatrick skin scale

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_predict

# Example DataFrame structure (assuming df is already defined)
# df = pd.DataFrame({...})

# Prepare the training data
X_train = df.dropna(subset=['combined_race'])[['dermatologist_fitzpatrick_skin_type_label']]
y_train = df.dropna(subset=['combined_race'])['combined_race']

# Encoding the target variable
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)

# Encoding the feature
feature_encoder = LabelEncoder()
X_train_encoded = feature_encoder.fit_transform(X_train.values.ravel()).reshape(-1, 1)

# Initializing and training the model
model = RandomForestClassifier(random_state=42)
model.fit(X_train_encoded, y_train_encoded)

# Predict missing values for combined_race
X_predict = df[df['combined_race'].isnull()][['dermatologist_fitzpatrick_skin_type_label']]
X_predict_encoded = feature_encoder.transform(X_predict.values.ravel()).reshape(-1, 1)

# Make predictions
predicted_values_encoded = model.predict(X_predict_encoded)

# Decode the predicted values
predicted_values = label_encoder.inverse_transform(predicted_values_encoded)

# Update DataFrame with predicted values
df.loc[df['combined_race'].isnull(), 'combined_race'] = predicted_values

# %%
df['combined_race'].value_counts().sum()
# Out:
# 5033

# %% [markdown]
# ### Predict the user given fitzpatrick skin type using the race ethnicity feature

# %%
# Split the dataset into training and test sets
from sklearn.preprocessing import LabelEncoder

train_data = df.dropna(subset=["fitzpatrick_skin_type", "race_ethnicity"])
test_data = df[df["fitzpatrick_skin_type"].isnull()]

# Encode categorical variables
label_encoder = LabelEncoder()
train_data["race_ethnicity_encoded"] = label_encoder.fit_transform(train_data["race_ethnicity"])
test_data["race_ethnicity_encoded"] = label_encoder.transform(test_data["race_ethnicity"])

# Define features and target variable
features = ["race_ethnicity_encoded"]
target = "fitzpatrick_skin_type"

# Train a Random Forest Classifier
rf_classifier = RandomForestClassifier()
rf_classifier.fit(train_data[features], train_data[target])

# Predict missing values
predicted_skin_types = rf_classifier.predict(test_data[features])

# Update the missing values in the original dataset
df.loc[df["fitzpatrick_skin_type"].isnull(), "fitzpatrick_skin_type"] = predicted_skin_types
# Out:
# <ipython-input-197-e3e7501ab42c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data["race_ethnicity_encoded"] = label_encoder.fit_transform(train_data["race_ethnicity"])
# <ipython-input-197-e3e7501ab42c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data["race_ethnicity_encoded"] = label_encoder.transform(test_data["race_ethnicity"])

# %%
df['fitzpatrick_skin_type'].value_counts().sum()
# Out:
# 5033

# %% [markdown]
# ### Replcae the missing values of condition_duration and related_category columns with unknwon (you can predict the values in this columns using CNN for the images)

# %%
columns_to_replace = ['race_ethnicity', 'textures', 'body_parts', 'condition_symptoms', 'other_symptoms']
df[columns_to_replace] = df[columns_to_replace].replace('', np.nan)

# %%
df['condition_duration'] = df['condition_duration'].replace(np.nan, 'UNKNOWN')
df['related_category'] = df['related_category'].replace(np.nan, 'OTHER_ISSUE_DESCRIPTION')

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>9.Droping Columns </b></h1>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5033 entries, 0 to 5032
# Data columns (total 39 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   case_id                                             5033 non-null   object
#  1   source                                              5033 non-null   object
#  2   release                                             5033 non-null   object
#  3   year                                                5033 non-null   int64
#  4   age_group                                           5032 non-null   object
#  5   sex_at_birth                                        5032 non-null   object
#  6   fitzpatrick_skin_type                               5033 non-null   object
#  7   related_category                                    5033 non-null   object
#  8   condition_duration                                  5033 non-null   object
#  9   image_1_path                                        5033 non-null   object
#  10  image_2_path                                        3085 non-null   object
#  11  image_3_path                                        2289 non-null   object
#  12  image_1_shot_type                                   5033 non-null   object
#  13  image_2_shot_type                                   3085 non-null   object
#  14  image_3_shot_type                                   2290 non-null   object
#  15  combined_race                                       5033 non-null   object
#  16  race_ethnicity_two_or_more_after_mitigation         83 non-null     object
#  17  dermatologist_gradable_for_skin_condition_1         5033 non-null   object
#  18  dermatologist_gradable_for_skin_condition_2         716 non-null    object
#  19  dermatologist_gradable_for_skin_condition_3         716 non-null    object
#  20  dermatologist_skin_condition_on_label_name          5033 non-null   object
#  21  dermatologist_skin_condition_confidence             5033 non-null   object
#  22  weighted_skin_condition_label                       5033 non-null   object
#  23  dermatologist_gradable_for_fitzpatrick_skin_type_1  5033 non-null   object
#  24  dermatologist_gradable_for_fitzpatrick_skin_type_2  716 non-null    object
#  25  dermatologist_gradable_for_fitzpatrick_skin_type_3  716 non-null    object
#  26  dermatologist_fitzpatrick_skin_type_label_1         4370 non-null   object
#  27  dermatologist_fitzpatrick_skin_type_label_2         634 non-null    object
#  28  dermatologist_fitzpatrick_skin_type_label_3         631 non-null    object
#  29  gradable_for_monk_skin_tone_india                   5033 non-null   object
#  30  gradable_for_monk_skin_tone_us                      5033 non-null   object
#  31  monk_skin_tone_label_india                          5033 non-null   float64
#  32  monk_skin_tone_label_us                             5033 non-null   float64
#  33  race_ethnicity                                      2569 non-null   object
#  34  textures                                            4079 non-null   object
#  35  body_parts                                          4085 non-null   object
#  36  condition_symptoms                                  3770 non-null   object
#  37  other_symptoms                                      3508 non-null   object
#  38  dermatologist_fitzpatrick_skin_type_label           5033 non-null   object
# dtypes: float64(2), int64(1), object(36)
# memory usage: 1.5+ MB

# %%
for column in df.columns:
    print(df[column].value_counts())
    print('========================================================')
# Out:
# case_id
# -1000600354148496558    1
# 3798503331105153312     1
# 3840593403086739651     1
# 3831326209815553185     1
# 3818341938433690215     1
#                        ..
# -6485961062381271236    1
# -6485947403303154678    1
# -6485920953755598815    1
# -6484363516740850665    1
# 998890198757718998      1
# Name: count, Length: 5033, dtype: int64
# ========================================================
# source
# SCIN    5033
# Name: count, dtype: int64
# ========================================================
# release
# 1.0.0    5033
# Name: count, dtype: int64
# ========================================================
# year
# 2023    5033
# Name: count, dtype: int64
# ========================================================
# age_group
# AGE_UNKNOWN     2864
# AGE_18_TO_29     769
# AGE_40_TO_49     435
# AGE_30_TO_39     422
# AGE_50_TO_59     322
# AGE_60_TO_69     165
# AGE_70_TO_79      55
# Name: count, dtype: int64
# ========================================================
# sex_at_birth
# OTHER_OR_UNSPECIFIED    2559
# FEMALE                  1666
# MALE                     807
# Name: count, dtype: int64
# ========================================================
# fitzpatrick_skin_type
# FST3               3140
# FST2                542
# FST4                449
# NONE_IDENTIFIED     357
# FST5                214
# FST1                188
# FST6                143
# Name: count, dtype: int64
# ========================================================
# related_category
# RASH                       2876
# OTHER_ISSUE_DESCRIPTION    1668
# LOOKS_HEALTHY               290
# ACNE                         74
# GROWTH_OR_MOLE               45
# PIGMENTARY_PROBLEM           37
# NAIL_PROBLEM                 20
# OTHER_HAIR_PROBLEM           12
# HAIR_LOSS                    11
# Name: count, dtype: int64
# ========================================================
# condition_duration
# LESS_THAN_ONE_WEEK        1386
# UNKNOWN                   1036
# ONE_TO_FOUR_WEEKS          960
# ONE_DAY                    784
# ONE_TO_THREE_MONTHS        318
# THREE_TO_TWELVE_MONTHS     237
# MORE_THAN_ONE_YEAR         201
# MORE_THAN_FIVE_YEARS        91
# SINCE_CHILDHOOD             20
# Name: count, dtype: int64
# ========================================================
# image_1_path
# dataset/images/5520969433413629950.png     11
# dataset/images/-8351498747234518768.png     3
# dataset/images/-9111307368692396870.png     3
# dataset/images/4166674568332648445.png      2
# dataset/images/-25790440481901575.png       2
#                                            ..
# dataset/images/-4573976021745395128.png     1
# dataset/images/7120089320578618718.png      1
# dataset/images/-2495405375565733468.png     1
# dataset/images/-5922125062125760989.png     1
# dataset/images/8953015289412905592.png      1
# Name: count, Length: 5013, dtype: int64
# ========================================================
# image_2_path
# dataset/images/265617434552206306.png      3
# dataset/images/-8431449183703420205.png    2
# dataset/images/1851972142048297272.png     2
# dataset/images/4013268428021902865.png     2
# dataset/images/8270654112785798156.png     2
#                                           ..
# dataset/images/1057317580683889847.png     1
# dataset/images/2935313772061335716.png     1
# dataset/images/-8513074287715511720.png    1
# dataset/images/428235017399500356.png      1
# dataset/images/-8850087380548289976.png    1
# Name: count, Length: 3079, dtype: int64
# ========================================================
# image_3_path
# dataset/images/9068834759287693167.png     2
# dataset/images/742075435141960831.png      1
# dataset/images/4616288950316844241.png     1
# dataset/images/9167063938168637187.png     1
# dataset/images/4871828783774878817.png     1
#                                           ..
# dataset/images/5092072349779526314.png     1
# dataset/images/-7528154962745771642.png    1
# dataset/images/1803609261729241427.png     1
# dataset/images/964795081456203750.png      1
# dataset/images/1619983824061709467.png     1
# Name: count, Length: 2288, dtype: int64
# ========================================================
# image_1_shot_type
# CLOSE_UP       3082
# AT_AN_ANGLE    1139
# AT_DISTANCE     812
# Name: count, dtype: int64
# ========================================================
# image_2_shot_type
# CLOSE_UP       1201
# AT_AN_ANGLE    1110
# AT_DISTANCE     774
# Name: count, dtype: int64
# ========================================================
# image_3_shot_type
# AT_DISTANCE    778
# AT_AN_ANGLE    766
# CLOSE_UP       746
# Name: count, dtype: int64
# ========================================================
# combined_race
# WHITE                                                          3888
# BLACK_OR_AFRICAN_AMERICAN                                       522
# HISPANIC_LATINO_OR_SPANISH_ORIGIN                               224
# ASIAN                                                            85
# TWO_OR_MORE_AFTER_MITIGATION                                     83
# HISPANIC_LATINO_OR_SPANISH_ORIGIN,WHITE                          55
# AMERICAN_INDIAN_OR_ALASKA_NATIVE                                 48
# PREFER_NOT_TO_ANSWER                                             34
# AMERICAN_INDIAN_OR_ALASKA_NATIVE,WHITE                           25
# BLACK_OR_AFRICAN_AMERICAN,WHITE                                  20
# OTHER_RACE                                                       16
# BLACK_OR_AFRICAN_AMERICAN,HISPANIC_LATINO_OR_SPANISH_ORIGIN      11
# ASIAN,WHITE                                                      11
# MIDDLE_EASTERN_OR_NORTH_AFRICAN                                   7
# NATIVE_HAWAIIAN_OR_PACIFIC_ISLANDER                               4
# Name: count, dtype: int64
# ========================================================
# race_ethnicity_two_or_more_after_mitigation
# YES    83
# Name: count, dtype: int64
# ========================================================
# dermatologist_gradable_for_skin_condition_1
# DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT                     3006
# NO_IMAGE_QUALITY_INSUFFICIENT                            1968
# YES_IMAGE_QUALITY_SUFFICIENT_NO_DISCERNIBLE_PATHOLOGY      59
# Name: count, dtype: int64
# ========================================================
# dermatologist_gradable_for_skin_condition_2
# DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT                     464
# NO_IMAGE_QUALITY_INSUFFICIENT                            245
# YES_IMAGE_QUALITY_SUFFICIENT_NO_DISCERNIBLE_PATHOLOGY      7
# Name: count, dtype: int64
# ========================================================
# dermatologist_gradable_for_skin_condition_3
# DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT                     461
# NO_IMAGE_QUALITY_INSUFFICIENT                            243
# YES_IMAGE_QUALITY_SUFFICIENT_NO_DISCERNIBLE_PATHOLOGY     12
# Name: count, dtype: int64
# ========================================================
# dermatologist_skin_condition_on_label_name
# []                                                                                                                 1972
# ['Eczema']                                                                                                          120
# ['Urticaria']                                                                                                        81
# ['Eczema', 'Allergic Contact Dermatitis']                                                                            67
# ['Allergic Contact Dermatitis', 'Irritant Contact Dermatitis']                                                       60
#                                                                                                                    ...
# ['Impetigo', 'Fungal dermatosis', 'Molluscum Contagiosum']                                                            1
# ['Stasis Dermatitis', 'Pigmented purpuric eruption', 'Hemosiderin pigmentation of skin']                              1
# ['Phytophotodermatitis', 'Allergic Contact Dermatitis', 'Insect Bite', 'Eczema', 'Allergic Contact Dermatitis']       1
# ['Drug Rash', 'Viral Exanthem', 'Miliaria']                                                                           1
# ['Erythema gyratum repens', 'Seborrheic Dermatitis', 'Erythema marginatum in acute rheumatic fever']                  1
# Name: count, Length: 1715, dtype: int64
# ========================================================
# dermatologist_skin_condition_confidence
# []                       1972
# [5]                       312
# [4]                       208
# [2, 2, 2]                 178
# [2, 2]                    176
#                          ...
# [1, 5, 4]                   1
# [2, 3, 2, 1, 1, 1]          1
# [1, 5, 1, 5, 1, 1, 5]       1
# [2, 2, 3, 3, 1, 4]          1
# [3, 4, 2, 5]                1
# Name: count, Length: 547, dtype: int64
# ========================================================
# weighted_skin_condition_label
# {}                                                                                                                        1972
# {'Eczema': 1.0}                                                                                                            127
# {'Urticaria': 1.0}                                                                                                          85
# {'Allergic Contact Dermatitis': 1.0}                                                                                        42
# {'Folliculitis': 1.0}                                                                                                       38
#                                                                                                                           ...
# {'Prurigo nodularis': 0.67, 'Lichen Simplex Chronicus': 0.33}                                                                1
# {'Leukocytoclastic Vasculitis': 0.55, 'Pigmented purpuric eruption': 0.27, 'Stasis Dermatitis': 0.18}                        1
# {'Scabies': 0.55, 'Insect Bite': 0.27, 'Eczema': 0.18}                                                                       1
# {'Erythema gyratum repens': 0.67, 'Drug Rash': 0.33}                                                                         1
# {'Erythema gyratum repens': 0.33, 'Seborrheic Dermatitis': 0.33, 'Erythema marginatum in acute rheumatic fever': 0.33}       1
# Name: count, Length: 1942, dtype: int64
# ========================================================
# dermatologist_gradable_for_fitzpatrick_skin_type_1
# YES    4331
# NO      702
# Name: count, dtype: int64
# ========================================================
# dermatologist_gradable_for_fitzpatrick_skin_type_2
# YES    634
# NO      82
# Name: count, dtype: int64
# ========================================================
# dermatologist_gradable_for_fitzpatrick_skin_type_3
# YES    631
# NO      85
# Name: count, dtype: int64
# ========================================================
# dermatologist_fitzpatrick_skin_type_label_1
# FST2    1491
# FST3    1351
# FST4     716
# FST1     381
# FST5     364
# FST6      67
# Name: count, dtype: int64
# ========================================================
# dermatologist_fitzpatrick_skin_type_label_2
# FST2    243
# FST3    172
# FST4    119
# FST5     52
# FST1     42
# FST6      6
# Name: count, dtype: int64
# ========================================================
# dermatologist_fitzpatrick_skin_type_label_3
# FST2    234
# FST3    190
# FST4    119
# FST5     58
# FST1     30
# Name: count, dtype: int64
# ========================================================
# gradable_for_monk_skin_tone_india
# True                  5025
# 0.9978826198506683       4
# False                    4
# Name: count, dtype: int64
# ========================================================
# gradable_for_monk_skin_tone_us
# True                  5014
# False                   18
# 0.9876568579950934       1
# Name: count, dtype: int64
# ========================================================
# monk_skin_tone_label_india
# 2.0    2441
# 3.0    1591
# 4.0     522
# 1.0     187
# 5.0     177
# 6.0      63
# 7.0      35
# 8.0      14
# 9.0       3
# Name: count, dtype: int64
# ========================================================
# monk_skin_tone_label_us
# 2.0     1688
# 3.0     1265
# 4.0      687
# 1.0      577
# 5.0      361
# 6.0      248
# 7.0      137
# 8.0       57
# 9.0       11
# 10.0       2
# Name: count, dtype: int64
# ========================================================
# race_ethnicity
# race_ethnicity_white                                  1873
# race_ethnicity_black_or_african_american               267
# race_ethnicity_hispanic_latino_or_spanish_origin       235
# race_ethnicity_asian                                    85
# race_ethnicity_american_indian_or_alaska_native         48
# race_ethnicity_prefer_not_to_answer                     34
# race_ethnicity_other_race                               16
# race_ethnicity_middle_eastern_or_north_african           7
# race_ethnicity_native_hawaiian_or_pacific_islander       4
# Name: count, dtype: int64
# ========================================================
# textures
# textures_raised_or_bumpy    1907
# textures_rough_or_flaky      870
# textures_flat                673
# textures_fluid_filled        629
# Name: count, dtype: int64
# ========================================================
# body_parts
# body_parts_leg                   1330
# body_parts_arm                    707
# body_parts_other                  543
# body_parts_foot_top_or_side       313
# body_parts_torso_back             252
# body_parts_head_or_neck           228
# body_parts_torso_front            208
# body_parts_back_of_hand           189
# body_parts_buttocks                97
# body_parts_foot_sole               94
# body_parts_genitalia_or_groin      70
# body_parts_palm                    54
# Name: count, dtype: int64
# ========================================================
# condition_symptoms
# condition_symptoms_itching                   1695
# condition_symptoms_pain                       734
# condition_symptoms_burning                    514
# condition_symptoms_bothersome_appearance      313
# condition_symptoms_no_relevant_experience     308
# condition_symptoms_increasing_size            122
# condition_symptoms_darkening                   78
# condition_symptoms_bleeding                     6
# Name: count, dtype: int64
# ========================================================
# other_symptoms
# other_symptoms_no_relevant_symptoms    2841
# other_symptoms_joint_pain               220
# other_symptoms_fatigue                  188
# other_symptoms_shortness_of_breath      139
# other_symptoms_mouth_sores               71
# other_symptoms_chills                    31
# other_symptoms_fever                     18
# Name: count, dtype: int64
# ========================================================
# dermatologist_fitzpatrick_skin_type_label
# FST2    1844
# FST3    1583
# FST4     765
# FST5     389
# FST1     383
# FST6      69
# Name: count, dtype: int64
# ========================================================

# %%
indices_to_remove = [0, 1, 2, 3, 16, 18, 19, 20, 21, 24, 25, 26, 27, 28, 29, 30]
df.drop(df.columns[indices_to_remove], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5033 entries, 0 to 5032
# Data columns (total 23 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   age_group                                           5032 non-null   object
#  1   sex_at_birth                                        5032 non-null   object
#  2   fitzpatrick_skin_type                               5033 non-null   object
#  3   related_category                                    5033 non-null   object
#  4   condition_duration                                  5033 non-null   object
#  5   image_1_path                                        5033 non-null   object
#  6   image_2_path                                        3085 non-null   object
#  7   image_3_path                                        2289 non-null   object
#  8   image_1_shot_type                                   5033 non-null   object
#  9   image_2_shot_type                                   3085 non-null   object
#  10  image_3_shot_type                                   2290 non-null   object
#  11  combined_race                                       5033 non-null   object
#  12  dermatologist_gradable_for_skin_condition_1         5033 non-null   object
#  13  weighted_skin_condition_label                       5033 non-null   object
#  14  dermatologist_gradable_for_fitzpatrick_skin_type_1  5033 non-null   object
#  15  monk_skin_tone_label_india                          5033 non-null   float64
#  16  monk_skin_tone_label_us                             5033 non-null   float64
#  17  race_ethnicity                                      2569 non-null   object
#  18  textures                                            4079 non-null   object
#  19  body_parts                                          4085 non-null   object
#  20  condition_symptoms                                  3770 non-null   object
#  21  other_symptoms                                      3508 non-null   object
#  22  dermatologist_fitzpatrick_skin_type_label           5033 non-null   object
# dtypes: float64(2), object(21)
# memory usage: 904.5+ KB

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>10.feature Engineering Part 2 </b></h1>
# </div>

# %%
import re
def get_expected_condition(condition_str):
    if condition_str == '{}':
        return None

    # Extract key-value pairs
    pairs = re.findall(r"'(.*?)': ([\d.]+)", condition_str)

    if not pairs:
        return None

    # Find the key with the maximum value
    max_key = max(pairs, key=lambda x: float(x[1]))[0]
    return max_key

# Apply the function to the DataFrame
df['Expected Condition'] = df['weighted_skin_condition_label'].apply(get_expected_condition)
df['Expected Condition'].value_counts().sum()
# Out:
# 3061

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>11.Rename the Columns and its Values </b></h1>
# </div>

# %%
df.head(10)
# Out:
#       age_group          sex_at_birth fitzpatrick_skin_type  \
# 0   AGE_UNKNOWN  OTHER_OR_UNSPECIFIED                  FST3
# 1   AGE_UNKNOWN  OTHER_OR_UNSPECIFIED                  FST3
# 2  AGE_18_TO_29                  MALE       NONE_IDENTIFIED
# 3   AGE_UNKNOWN  OTHER_OR_UNSPECIFIED                  FST3
# 4  AGE_40_TO_49                FEMALE                  FST3
# 5   AGE_UNKNOWN  OTHER_OR_UNSPECIFIED                  FST3
# 6  AGE_40_TO_49                FEMALE                  FST1
# 7   AGE_UNKNOWN                  MALE                  FST4
# 8  AGE_18_TO_29                  MALE                  FST2
# 9   AGE_UNKNOWN  OTHER_OR_UNSPECIFIED                  FST3
#
#           related_category   condition_duration  \
# 0                     RASH              ONE_DAY
# 1  OTHER_ISSUE_DESCRIPTION              UNKNOWN
# 2  OTHER_ISSUE_DESCRIPTION    ONE_TO_FOUR_WEEKS
# 3  OTHER_ISSUE_DESCRIPTION              ONE_DAY
# 4                     RASH              ONE_DAY
# 5                     RASH   LESS_THAN_ONE_WEEK
# 6                     RASH   LESS_THAN_ONE_WEEK
# 7                     RASH  ONE_TO_THREE_MONTHS
# 8                     RASH  ONE_TO_THREE_MONTHS
# 9  OTHER_ISSUE_DESCRIPTION              UNKNOWN
#
#                               image_1_path  \
# 0  dataset/images/-3205742176803893704.png
# 1  dataset/images/-4762289084741430925.png
# 2  dataset/images/-4027806997035329030.png
# 3  dataset/images/-5332065579713135540.png
# 4  dataset/images/-3799298995660217860.png
# 5  dataset/images/-3575683440831198879.png
# 6  dataset/images/-6942912841265248602.png
# 7   dataset/images/-220649468572111832.png
# 8   dataset/images/-217828380359571871.png
# 9   dataset/images/8406712750126834903.png
#
#                               image_2_path  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3  dataset/images/-6353431708064969797.png
# 4  dataset/images/-5881426422999442186.png
# 5   dataset/images/6164754101533643044.png
# 6   dataset/images/-815168034213335912.png
# 7                                      NaN
# 8  dataset/images/-4055728304670056584.png
# 9                                      NaN
#
#                              image_3_path image_1_shot_type image_2_shot_type  \
# 0                                     NaN          CLOSE_UP               NaN
# 1                                     NaN          CLOSE_UP               NaN
# 2                                     NaN          CLOSE_UP               NaN
# 3   dataset/images/742075435141960831.png       AT_DISTANCE       AT_AN_ANGLE
# 4  dataset/images/5854025080806696361.png       AT_AN_ANGLE       AT_DISTANCE
# 5  dataset/images/7125798012232703466.png          CLOSE_UP       AT_AN_ANGLE
# 6  dataset/images/8479707042238010445.png       AT_AN_ANGLE       AT_DISTANCE
# 7                                     NaN          CLOSE_UP               NaN
# 8                                     NaN          CLOSE_UP       AT_AN_ANGLE
# 9                                     NaN          CLOSE_UP               NaN
#
#   image_3_shot_type                      combined_race  \
# 0               NaN                              WHITE
# 1               NaN                              WHITE
# 2               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 3          CLOSE_UP                              WHITE
# 4          CLOSE_UP                              WHITE
# 5       AT_DISTANCE                              WHITE
# 6          CLOSE_UP  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 7               NaN                              WHITE
# 8               NaN  HISPANIC_LATINO_OR_SPANISH_ORIGIN
# 9               NaN                              WHITE
#
#   dermatologist_gradable_for_skin_condition_1  \
# 0        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 1        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 2        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 3               NO_IMAGE_QUALITY_INSUFFICIENT
# 4        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 5        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 6        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 7        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 8        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
# 9        DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT
#
#                        weighted_skin_condition_label  \
# 0  {'Inflicted skin lesions': 0.41, 'Eczema': 0.4...
# 1  {'Prurigo nodularis': 0.41, 'SCC/SCCIS': 0.41,...
# 2  {'Impetigo': 0.55, 'Herpes Zoster': 0.23, 'Bul...
# 3                                                 {}
# 4  {'Lichen planus/lichenoid eruption': 0.33, 'Fo...
# 5  {'Drug Rash': 0.41, 'Viral Exanthem': 0.41, 'E...
# 6  {'Urticaria': 0.6, 'Leukocytoclastic Vasculiti...
# 7  {'Basal Cell Carcinoma': 0.55, 'Inflicted skin...
# 8  {'Eczema': 0.67, 'Psoriasis': 0.11, 'Acute and...
# 9                                   {'Purpura': 1.0}
#
#   dermatologist_gradable_for_fitzpatrick_skin_type_1  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                 NO
# 4                                                YES
# 5                                                YES
# 6                                                YES
# 7                                                YES
# 8                                                YES
# 9                                                YES
#
#    monk_skin_tone_label_india  monk_skin_tone_label_us  \
# 0                         2.0                      1.0
# 1                         3.0                      3.0
# 2                         3.0                      4.0
# 3                         2.0                      4.0
# 4                         1.0                      1.0
# 5                         2.0                      2.0
# 6                         3.0                      3.0
# 7                         3.0                      4.0
# 8                         2.0                      4.0
# 9                         3.0                      3.0
#
#                                      race_ethnicity                  textures  \
# 0                                               NaN  textures_raised_or_bumpy
# 1                                               NaN                       NaN
# 2  race_ethnicity_hispanic_latino_or_spanish_origin   textures_rough_or_flaky
# 3                                               NaN   textures_rough_or_flaky
# 4                              race_ethnicity_white             textures_flat
# 5                                               NaN  textures_raised_or_bumpy
# 6  race_ethnicity_hispanic_latino_or_spanish_origin  textures_raised_or_bumpy
# 7                              race_ethnicity_white  textures_raised_or_bumpy
# 8  race_ethnicity_hispanic_latino_or_spanish_origin             textures_flat
# 9                                               NaN                       NaN
#
#                       body_parts            condition_symptoms  \
# 0    body_parts_foot_top_or_side       condition_symptoms_pain
# 1                            NaN                           NaN
# 2                 body_parts_arm       condition_symptoms_pain
# 3                body_parts_palm       condition_symptoms_pain
# 4    body_parts_foot_top_or_side    condition_symptoms_itching
# 5  body_parts_genitalia_or_groin    condition_symptoms_itching
# 6                body_parts_palm    condition_symptoms_burning
# 7          body_parts_torso_back       condition_symptoms_pain
# 8                 body_parts_arm  condition_symptoms_darkening
# 9                            NaN                           NaN
#
#                         other_symptoms  \
# 0  other_symptoms_no_relevant_symptoms
# 1                                  NaN
# 2  other_symptoms_no_relevant_symptoms
# 3  other_symptoms_no_relevant_symptoms
# 4  other_symptoms_no_relevant_symptoms
# 5  other_symptoms_no_relevant_symptoms
# 6  other_symptoms_no_relevant_symptoms
# 7  other_symptoms_no_relevant_symptoms
# 8  other_symptoms_no_relevant_symptoms
# 9                                  NaN
#
#   dermatologist_fitzpatrick_skin_type_label                Expected Condition
# 0                                      FST2            Inflicted skin lesions
# 1                                      FST1                 Prurigo nodularis
# 2                                      FST4                          Impetigo
# 3                                      FST2                              None
# 4                                      FST1  Lichen planus/lichenoid eruption
# 5                                      FST3                         Drug Rash
# 6                                      FST4                         Urticaria
# 7                                      FST3              Basal Cell Carcinoma
# 8                                      FST4                            Eczema
# 9                                      FST4                           Purpura

# %%
# Assuming df is your DataFrame
df['age_group'] = df['age_group'].str.lower()
df['age_group'] = df['age_group'].str.replace('AGE_', '')  # Remove the prefix 'AGE_'
df['age_group'] = df['age_group'].str.replace('_TO_', ' to ')
df['age_group'].value_counts()
# Out:
# age_group
# age_unknown     2864
# age_18_to_29     769
# age_40_to_49     435
# age_30_to_39     422
# age_50_to_59     322
# age_60_to_69     165
# age_70_to_79      55
# Name: count, dtype: int64

# %%
df['related_category'] = df['related_category'].str.lower()
df['related_category'] = df['related_category'].str.replace('_',' ')
df['related_category'].value_counts()
# Out:
# related_category
# rash                       2876
# other issue description    1668
# looks healthy               290
# acne                         74
# growth or mole               45
# pigmentary problem           37
# nail problem                 20
# other hair problem           12
# hair loss                    11
# Name: count, dtype: int64

# %%
df['condition_duration'] = df['condition_duration'].str.replace('_', ' ')
df['condition_duration'] = df['condition_duration'].str.lower()
df['condition_duration'].value_counts()
# Out:
# condition_duration
# less than one week        1386
# unknown                   1036
# one to four weeks          960
# one day                    784
# one to three months        318
# three to twelve months     237
# more than one year         201
# more than five years        91
# since childhood             20
# Name: count, dtype: int64

# %%
df['image_1_shot_type'] = df['image_1_shot_type'].str.replace('_',' ')
df['image_1_shot_type'] = df['image_1_shot_type'].str.lower()

df['image_2_shot_type'] = df['image_2_shot_type'].str.replace('_',' ')
df['image_2_shot_type'] = df['image_2_shot_type'].str.lower()

df['image_3_shot_type'] = df['image_3_shot_type'].str.replace('_',' ')
df['image_3_shot_type'] = df['image_3_shot_type'].str.lower()
df['image_1_shot_type'].value_counts()
# Out:
# image_1_shot_type
# close up       3082
# at an angle    1139
# at distance     812
# Name: count, dtype: int64

# %%
df['sex_at_birth'] = df['sex_at_birth'].str.replace('_', ' ')
df['sex_at_birth'] = df['sex_at_birth'].str.lower()
df['sex_at_birth'] = df['sex_at_birth'].replace('other or unspecified', 'unspecified')
df['sex_at_birth'].value_counts()
# Out:
# sex_at_birth
# unspecified    2559
# female         1666
# male            807
# Name: count, dtype: int64

# %%
df['fitzpatrick_skin_type'] = df['fitzpatrick_skin_type'].str.replace('_', ' ')
df['fitzpatrick_skin_type'] = df['fitzpatrick_skin_type'].str.lower()
df['fitzpatrick_skin_type'].value_counts()
# Out:
# fitzpatrick_skin_type
# fst3               3140
# fst2                542
# fst4                449
# none identified     357
# fst5                214
# fst1                188
# fst6                143
# Name: count, dtype: int64

# %%
df['combined_race'] = df['combined_race'].str.replace('_', ' ')
df['combined_race'] = df['combined_race'].str.lower()

replacement_dict = {
    'DEFAULT_YES_IMAGE_QUALITY_SUFFICIENT': 'quality sufficient',
    'NO_IMAGE_QUALITY_INSUFFICIENT': 'quality insufficient',
    'YES_IMAGE_QUALITY_SUFFICIENT_NO_DISCERNIBLE_PATHOLOGY': 'sufficient with no pathology'
}
df['dermatologist_gradable_for_skin_condition_1'] = df['dermatologist_gradable_for_skin_condition_1'].replace(replacement_dict)

df['race_ethnicity'] = df['race_ethnicity'].str.split('race_ethnicity').str[1]
df['race_ethnicity'] = df['race_ethnicity'].str.lower()
df['race_ethnicity'] = df['race_ethnicity'].str.replace('_', ' ')

# %%
df['body_parts'] = df['body_parts'].str.split('body_parts').str[1]
df['body_parts'] = df['body_parts'].str.lower()
df['body_parts'] = df['body_parts'].str.replace('_', ' ')

df['condition_symptoms'] = df['condition_symptoms'].str.split('condition_symptoms').str[1]
df['condition_symptoms'] = df['condition_symptoms'].str.lower()
df['condition_symptoms'] = df['condition_symptoms'].str.replace('_', ' ')

df['other_symptoms'] = df['other_symptoms'].str.split('other_symptoms').str[1]
df['other_symptoms'] = df['other_symptoms'].str.lower()
df['other_symptoms'] = df['other_symptoms'].str.replace('_', ' ')

# %%
df['textures'] = df['textures'].str.split('textures').str[1]
df['textures'] = df['textures'].str.lower()
df['textures'] = df['textures'].str.replace('_', ' ')

# %%
df.drop(['race_ethnicity', 'image_2_path', 'image_3_path', 'image_2_shot_type', 'image_3_shot_type'], axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5033 entries, 0 to 5032
# Data columns (total 19 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   age_group                                           5032 non-null   object
#  1   sex_at_birth                                        5032 non-null   object
#  2   fitzpatrick_skin_type                               5033 non-null   object
#  3   related_category                                    5033 non-null   object
#  4   condition_duration                                  5033 non-null   object
#  5   image_1_path                                        5033 non-null   object
#  6   image_1_shot_type                                   5033 non-null   object
#  7   combined_race                                       5033 non-null   object
#  8   dermatologist_gradable_for_skin_condition_1         5033 non-null   object
#  9   weighted_skin_condition_label                       5033 non-null   object
#  10  dermatologist_gradable_for_fitzpatrick_skin_type_1  5033 non-null   object
#  11  monk_skin_tone_label_india                          5033 non-null   float64
#  12  monk_skin_tone_label_us                             5033 non-null   float64
#  13  textures                                            4079 non-null   object
#  14  body_parts                                          4085 non-null   object
#  15  condition_symptoms                                  3770 non-null   object
#  16  other_symptoms                                      3508 non-null   object
#  17  dermatologist_fitzpatrick_skin_type_label           5033 non-null   object
#  18  Expected Condition                                  3061 non-null   object
# dtypes: float64(2), object(17)
# memory usage: 747.2+ KB

# %%
from sklearn.impute import SimpleImputer


columns_to_impute = ['textures', 'body_parts', 'condition_symptoms', 'other_symptoms', 'Expected Condition']

# Impute missing values using mean imputation
imputer = SimpleImputer(strategy='most_frequent')
df[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])

# %%
df['image_1_path'] = df['image_1_path'].apply(lambda x: x.split('/')[-1])

# %%
df.rename(columns={'fitzpatrick_skin_type':'fitzpatrick_scale',
                   'image_1_shot_type' : 'image_shot',
                   'dermatologist_gradable_for_skin_condition_1': 'image_sufficiency',
                   'dermatologist_fitzpatrick_skin_type_label': 'dermatologist_fitzpatrick_diagnosis',
                   'dermatologist_gradable_for_fitzpatrick_skin_type_1': 'dermatologist_gradable_fitzpatrick_diagnosis',
                   'image_1_path':'image_name'}, inplace=True)
df.head(10)
# Out:
#       age_group sex_at_birth fitzpatrick_scale         related_category  \
# 0   age_unknown  unspecified              fst3                     rash
# 1   age_unknown  unspecified              fst3  other issue description
# 2  age_18_to_29         male   none identified  other issue description
# 3   age_unknown  unspecified              fst3  other issue description
# 4  age_40_to_49       female              fst3                     rash
# 5   age_unknown  unspecified              fst3                     rash
# 6  age_40_to_49       female              fst1                     rash
# 7   age_unknown         male              fst4                     rash
# 8  age_18_to_29         male              fst2                     rash
# 9   age_unknown  unspecified              fst3  other issue description
#
#     condition_duration                image_name   image_shot  \
# 0              one day  -3205742176803893704.png     close up
# 1              unknown  -4762289084741430925.png     close up
# 2    one to four weeks  -4027806997035329030.png     close up
# 3              one day  -5332065579713135540.png  at distance
# 4              one day  -3799298995660217860.png  at an angle
# 5   less than one week  -3575683440831198879.png     close up
# 6   less than one week  -6942912841265248602.png  at an angle
# 7  one to three months   -220649468572111832.png     close up
# 8  one to three months   -217828380359571871.png     close up
# 9              unknown   8406712750126834903.png     close up
#
#                        combined_race     image_sufficiency  \
# 0                              white    quality sufficient
# 1                              white    quality sufficient
# 2  hispanic latino or spanish origin    quality sufficient
# 3                              white  quality insufficient
# 4                              white    quality sufficient
# 5                              white    quality sufficient
# 6  hispanic latino or spanish origin    quality sufficient
# 7                              white    quality sufficient
# 8  hispanic latino or spanish origin    quality sufficient
# 9                              white    quality sufficient
#
#                        weighted_skin_condition_label  \
# 0  {'Inflicted skin lesions': 0.41, 'Eczema': 0.4...
# 1  {'Prurigo nodularis': 0.41, 'SCC/SCCIS': 0.41,...
# 2  {'Impetigo': 0.55, 'Herpes Zoster': 0.23, 'Bul...
# 3                                                 {}
# 4  {'Lichen planus/lichenoid eruption': 0.33, 'Fo...
# 5  {'Drug Rash': 0.41, 'Viral Exanthem': 0.41, 'E...
# 6  {'Urticaria': 0.6, 'Leukocytoclastic Vasculiti...
# 7  {'Basal Cell Carcinoma': 0.55, 'Inflicted skin...
# 8  {'Eczema': 0.67, 'Psoriasis': 0.11, 'Acute and...
# 9                                   {'Purpura': 1.0}
#
#   dermatologist_gradable_fitzpatrick_diagnosis  monk_skin_tone_label_india  \
# 0                                          YES                         2.0
# 1                                          YES                         3.0
# 2                                          YES                         3.0
# 3                                           NO                         2.0
# 4                                          YES                         1.0
# 5                                          YES                         2.0
# 6                                          YES                         3.0
# 7                                          YES                         3.0
# 8                                          YES                         2.0
# 9                                          YES                         3.0
#
#    monk_skin_tone_label_us          textures           body_parts  \
# 0                      1.0   raised or bumpy     foot top or side
# 1                      3.0   raised or bumpy                  leg
# 2                      4.0    rough or flaky                  arm
# 3                      4.0    rough or flaky                 palm
# 4                      1.0              flat     foot top or side
# 5                      2.0   raised or bumpy   genitalia or groin
# 6                      3.0   raised or bumpy                 palm
# 7                      4.0   raised or bumpy           torso back
# 8                      4.0              flat                  arm
# 9                      3.0   raised or bumpy                  leg
#
#   condition_symptoms         other_symptoms  \
# 0               pain   no relevant symptoms
# 1            itching   no relevant symptoms
# 2               pain   no relevant symptoms
# 3               pain   no relevant symptoms
# 4            itching   no relevant symptoms
# 5            itching   no relevant symptoms
# 6            burning   no relevant symptoms
# 7               pain   no relevant symptoms
# 8          darkening   no relevant symptoms
# 9            itching   no relevant symptoms
#
#   dermatologist_fitzpatrick_diagnosis                Expected Condition
# 0                                FST2            Inflicted skin lesions
# 1                                FST1                 Prurigo nodularis
# 2                                FST4                          Impetigo
# 3                                FST2                              None
# 4                                FST1  Lichen planus/lichenoid eruption
# 5                                FST3                         Drug Rash
# 6                                FST4                         Urticaria
# 7                                FST3              Basal Cell Carcinoma
# 8                                FST4                            Eczema
# 9                                FST4                           Purpura

# %%
df.to_csv('Preproccessed_dataset.csv')

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>12.Data Visualization & Insights. </b></h1>
# </div>

# %%
df['age_group'].value_counts().plot(kind='bar', color='#ffd8a7')
plt.title('Distribution of age group')
plt.show()

# %%
df['fitzpatrick_scale'].value_counts().plot(kind='bar', color='#ffd8a7')
plt.title('Distribution of Fitzpatrick scale ratings')
plt.show()

# %%
df['condition_symptoms'].value_counts().plot(kind='pie',autopct='%1.1f%%', explode=[0.1, 0.15, 0.17, 0.2, 0.25, 0.3,0.35, 0.4],colors = ['#ffd8a7','#dc3545','#fd7f6f','#74b9ff','#a4d3ee'])
plt.title('Distribution of condition symptoms')
plt.show()

# %%
df['related_category'].value_counts().plot(kind='bar', color='#ffd8a7')
plt.title('Distribution of related categories')
plt.show()

# %%
df['combined_race'].value_counts().plot(kind='bar', color='#ffd8a7')
plt.title('Distribution of combined race')
plt.show()

# %% [markdown]
# <div style="text-align:center; background-color:#ffeeba; padding:20px;">
#   <h1 style="font-size:36px; color:#dc3545;"><b>13. Data Extraction </b></h1>
# </div>

# %%
df.to_csv('scin_dataset.csv')

# %%
import pandas as pd

def filter_images_by_name(dataframe, image_names):
    filtered_dataframe = dataframe[dataframe['image_name'].isin(image_names)]
    return filtered_dataframe

# Define the list of image names
image_names = [
    '2034844842573993364.png',
    '-6754223996189969134.png',
    '4091225911888174490.png',
    '-4649063046758807338.png',
    '-6544442737462623993.png',
    '-6480598833319500800.png',
    '-2197355568033743807.png',
    '-1240400659890187479.png',
    '-4328676342954471143.png',
    '-5609658706270241785.png',
    '4325542435903226725.png',
    '-3779989361448224309.png',
    '-1172506192366462495.png',
    '-773894958411105641.png',
    '-3205742176803893704.png',
    '-4639090956934471841.png',
    '-1153384974921559234.png',
    '-4893312442758095455.png',
    '-1943055598691963873.png',
    '-7030958736860719929.png',
    '-4335509512864210611.png',
    '-3796420587199097151.png',
    '-923054950838727613.png',
    '-7935950081089116729.png',
    '-446206036030978724.png'
]

# Filter the DataFrame based on the provided image names
filtered_df = filter_images_by_name(df, image_names)

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 0 to 4978
# Data columns (total 19 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   age_group                                     25 non-null     object
#  1   sex_at_birth                                  25 non-null     object
#  2   fitzpatrick_scale                             25 non-null     object
#  3   related_category                              25 non-null     object
#  4   condition_duration                            25 non-null     object
#  5   image_name                                    25 non-null     object
#  6   image_shot                                    25 non-null     object
#  7   combined_race                                 25 non-null     object
#  8   image_sufficiency                             25 non-null     object
#  9   weighted_skin_condition_label                 25 non-null     object
#  10  dermatologist_gradable_fitzpatrick_diagnosis  25 non-null     object
#  11  monk_skin_tone_label_india                    25 non-null     float64
#  12  monk_skin_tone_label_us                       25 non-null     float64
#  13  textures                                      25 non-null     object
#  14  body_parts                                    25 non-null     object
#  15  condition_symptoms                            25 non-null     object
#  16  other_symptoms                                25 non-null     object
#  17  dermatologist_fitzpatrick_diagnosis           25 non-null     object
#  18  Expected Condition                            15 non-null     object
# dtypes: float64(2), object(17)
# memory usage: 3.9+ KB

# %%
filtered_df.to_csv('val_scin.csv')
